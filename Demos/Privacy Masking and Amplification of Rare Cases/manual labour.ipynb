# %%
import pandas as pd
from faker import Faker
import random
import math

# %% [markdown]
# ## Load the data from data source

# %%
df = pd.read_csv('./finance.csv')

# %%
df.head(5)
# Out:
#      customer                    email age gender    merchant  \
# 0  C100045114  nmontgomery@example.net   4      M  M348934600
# 1  C100045114  nmontgomery@example.net   4      M  M348934600
# 2  C100045114  nmontgomery@example.net   4      M  M348934600
# 3  C100045114  nmontgomery@example.net   4      M  M348934600
# 4  C100045114  nmontgomery@example.net   4      M  M151143676
#
#              category  amount  fraud            timestamp
# 0      transportation   35.13      0  2023-01-01 00:00:00
# 1      transportation   27.63      0  2023-01-01 08:00:00
# 2      transportation   13.46      0  2023-01-01 16:00:00
# 3      transportation   28.86      0  2023-01-02 00:00:00
# 4  barsandrestaurants   64.99      0  2023-01-02 08:00:00

# %%
len(df)
# Out:
# 33688

# %%
len(df[df['fraud'] == 1])
# Out:
# 524

# %% [markdown]
# ## Goal: Need 50000 rows of synthetic data, with higher fraud and privacy protection

# %% [markdown]
# ### Step 1: clean data

# %%
df = df.dropna()

# %%
df = df[df['age'].str.isnumeric()]
df['age'] = df['age'].astype(int)

# %%
df['amount'] = df['amount'].astype(float)

# %%
df = df[df['gender'].isin(['M', 'F'])]

# %% [markdown]
# ### Step 2: create a mapping for dependent fields: customer id and email

# %%
# create a zip of customer id and email
customer = dict(zip(df['customer'], df['email']))

# %%
for i, c in enumerate(customer.keys()):
    customer[c] = [customer[c]] + [{'id': i}]

# %%
customer
# Out:
# {'C100045114': ['nmontgomery@example.net', {'id': 0}],
#  'C1000699316': ['knightlauren@example.org', {'id': 1}],
#  'C1002759277': ['morgan84@example.net', {'id': 2}],
#  'C1004109477': ['smithscott@example.com', {'id': 3}],
#  'C1004300450': ['shaunallison@example.net', {'id': 4}],
#  'C1005126300': ['andrea42@example.net', {'id': 5}],
#  'C1005495267': ['masonjames@example.net', {'id': 6}],
#  'C1005806982': ['bmills@example.net', {'id': 7}],
#  'C1006176917': ['todd26@example.org', {'id': 8}],
#  'C1007572087': ['chris28@example.com', {'id': 9}],
#  'C1007790716': ['wallerbrandon@example.net', {'id': 10}],
#  'C1008918174': ['isimmons@example.net', {'id': 11}],
#  'C1009080922': ['jessicafigueroa@example.net', {'id': 12}],
#  'C100992504': ['marywilson@example.net', {'id': 13}],
#  'C10105795': ['mckenzieerickson@example.org', {'id': 14}],
#  'C1010589026': ['zacharysantos@example.net', {'id': 15}],
#  'C1010865894': ['keith50@example.net', {'id': 16}],
#  'C1010936270': ['codydeleon@example.net', {'id': 17}],
#  'C1011693897': ['lisabrooks@example.com', {'id': 18}],
#  'C1012876398': ['rachelbell@example.com', {'id': 19}],
#  'C1013313546': ['ddickson@example.org', {'id': 20}],
#  'C1014010834': ['masonjoshua@example.org', {'id': 21}],
#  'C1014124305': ['hray@example.net', {'id': 22}],
#  'C1014313887': ['hannah31@example.org', {'id': 23}],
#  'C1014347664': ['ashleygonzalez@example.org', {'id': 24}],
#  'C1014847580': ['sosborne@example.com', {'id': 25}],
#  'C1017469037': ['urobbins@example.org', {'id': 26}],
#  'C1017941602': ['mallen@example.net', {'id': 27}],
#  'C1018153896': ['joelwebster@example.net', {'id': 28}],
#  'C1018388493': ['sandra07@example.net', {'id': 29}],
#  'C1018653381': ['dylan87@example.com', {'id': 30}],
#  'C1018783569': ['lhunter@example.com', {'id': 31}],
#  'C1018979501': ['james87@example.com', {'id': 32}],
#  'C1019071188': ['gina14@example.com', {'id': 33}],
#  'C1020019215': ['jennifermartinez@example.net', {'id': 34}],
#  'C102010508': ['barbara43@example.org', {'id': 35}],
#  'C1020355960': ['conwayhelen@example.com', {'id': 36}],
#  'C1021409246': ['hcarter@example.com', {'id': 37}],
#  'C1022153336': ['bennettlisa@example.net', {'id': 38}],
#  'C1022530210': ['chaseallison@example.com', {'id': 39}],
#  'C102256008': ['eruiz@example.com', {'id': 40}],
#  'C1022713215': ['esmith@example.org', {'id': 41}],
#  'C102364766': ['cmorrison@example.net', {'id': 42}],
#  'C1023694383': ['paynecrystal@example.com', {'id': 43}],
#  'C1023803355': ['timothy71@example.net', {'id': 44}],
#  'C1025104996': ['campbellmichael@example.com', {'id': 45}],
#  'C10263180': ['johnblake@example.com', {'id': 46}],
#  'C1027777422': ['angelaparks@example.org', {'id': 47}],
#  'C1028143403': ['danielleacosta@example.com', {'id': 48}],
#  'C1029994689': ['ywong@example.org', {'id': 49}],
#  'C1030484150': ['bellcassandra@example.com', {'id': 50}],
#  'C1030975170': ['uandrade@example.com', {'id': 51}],
#  'C1031698099': ['michelle83@example.com', {'id': 52}],
#  'C1032319289': ['pjohnston@example.com', {'id': 53}],
#  'C103240070': ['staylor@example.org', {'id': 54}],
#  'C1032715879': ['charlespadilla@example.com', {'id': 55}],
#  'C1033736586': ['gabriella39@example.net', {'id': 56}],
#  'C1033848759': ['kburns@example.com', {'id': 57}],
#  'C1034685704': ['marygonzalez@example.org', {'id': 58}],
#  'C1035222482': ['thomasperkins@example.com', {'id': 59}],
#  'C1035581047': ['allisonbaker@example.com', {'id': 60}],
#  'C1035666255': ['franklinhannah@example.net', {'id': 61}],
#  'C1035681921': ['amanda39@example.net', {'id': 62}],
#  'C1036903280': ['kmiller@example.net', {'id': 63}],
#  'C1037161656': ['gcruz@example.com', {'id': 64}],
#  'C1037622786': ['donnamiles@example.org', {'id': 65}],
#  'C1038215695': ['lisa40@example.com', {'id': 66}],
#  'C1038277619': ['thompsonzachary@example.com', {'id': 67}],
#  'C1038722314': ['ronald98@example.net', {'id': 68}],
#  'C1038733568': ['palmerrenee@example.org', {'id': 69}],
#  'C1038879380': ['taylorjonathan@example.com', {'id': 70}],
#  'C1038996959': ['frhodes@example.net', {'id': 71}],
#  'C1039035065': ['samantha92@example.com', {'id': 72}],
#  'C1039390058': ['murphylouis@example.net', {'id': 73}],
#  'C1039748502': ['nicolethompson@example.org', {'id': 74}],
#  'C1040272582': ['lisamccullough@example.org', {'id': 75}],
#  'C1040303644': ['nellis@example.net', {'id': 76}],
#  'C1040405455': ['samanthathompson@example.net', {'id': 77}],
#  'C1040980271': ['mariohernandez@example.net', {'id': 78}],
#  'C1043282651': ['richard60@example.org', {'id': 79}],
#  'C1043677034': ['maryperry@example.org', {'id': 80}],
#  'C104392148': ['brianbrown@example.net', {'id': 81}],
#  'C1043944424': ['roberthubbard@example.net', {'id': 82}],
#  'C1045214627': ['james40@example.net', {'id': 83}],
#  'C1045324088': ['harrisonmegan@example.net', {'id': 84}],
#  'C1045652139': ['jose77@example.net', {'id': 85}],
#  'C1046896257': ['garrett61@example.com', {'id': 86}],
#  'C1047374909': ['woodsann@example.net', {'id': 87}],
#  'C1047521541': ['stephenmoody@example.net', {'id': 88}],
#  'C1048588440': ['zachary18@example.com', {'id': 89}],
#  'C1048694975': ['alexandermiles@example.net', {'id': 90}],
#  'C1049562739': ['jessicaschmidt@example.net', {'id': 91}],
#  'C1049957303': ['duane20@example.org', {'id': 92}],
#  'C105013970': ['joseph61@example.net', {'id': 93}],
#  'C1050458046': ['tina57@example.net', {'id': 94}],
#  'C1050663079': ['jasontorres@example.org', {'id': 95}],
#  'C1050807234': ['anthonyjones@example.com', {'id': 96}],
#  'C1051356798': ['durantimothy@example.org', {'id': 97}],
#  'C1051682954': ['thomas99@example.org', {'id': 98}],
#  'C1051712338': ['moorejanet@example.net', {'id': 99}],
#  'C1051985937': ['katherine73@example.org', {'id': 100}],
#  'C1053477622': ['shane06@example.net', {'id': 101}],
#  'C1054818236': ['peterlee@example.com', {'id': 102}],
#  'C1055164842': ['cgarcia@example.com', {'id': 103}],
#  'C1055224400': ['joyramirez@example.org', {'id': 104}],
#  'C1056476734': ['sheila16@example.com', {'id': 105}],
#  'C1057259459': ['ronniebarrett@example.org', {'id': 106}],
#  'C1057285507': ['jonathan86@example.net', {'id': 107}],
#  'C1057813963': ['wesleyvega@example.net', {'id': 108}],
#  'C105845174': ['brandon99@example.org', {'id': 109}],
#  'C1058652489': ['mark94@example.com', {'id': 110}],
#  'C1058785965': ['vrodriguez@example.net', {'id': 111}],
#  'C1059534096': ['maria48@example.net', {'id': 112}],
#  'C1059874896': ['dylansmith@example.org', {'id': 113}],
#  'C1060018471': ['mcdanielderek@example.net', {'id': 114}],
#  'C1060120913': ['brownsteve@example.net', {'id': 115}],
#  'C1060270098': ['oadkins@example.net', {'id': 116}],
#  'C1060470494': ['rebecca68@example.net', {'id': 117}],
#  'C106333716': ['rebecca78@example.com', {'id': 118}],
#  'C1063753312': ['jstevenson@example.com', {'id': 119}],
#  'C106397937': ['donaldsonbrandon@example.org', {'id': 120}],
#  'C1065812935': ['brent63@example.com', {'id': 121}],
#  'C1066456457': ['elizabeth62@example.org', {'id': 122}],
#  'C1067134113': ['bakerthomas@example.org', {'id': 123}],
#  'C1067165398': ['ellisdeborah@example.net', {'id': 124}],
#  'C1067668919': ['keith55@example.net', {'id': 125}],
#  'C1067734462': ['smithisaiah@example.net', {'id': 126}],
#  'C106931168': ['stephanie18@example.net', {'id': 127}],
#  'C1069635670': ['kayla15@example.net', {'id': 128}],
#  'C1069648311': ['kelly33@example.net', {'id': 129}],
#  'C1070277785': ['thomasryan@example.org', {'id': 130}],
#  'C1070471979': ['robinhull@example.net', {'id': 131}],
#  'C107125195': ['justin88@example.com', {'id': 132}],
#  'C1072166767': ['mayochristopher@example.org', {'id': 133}],
#  'C1072577677': ['scottyu@example.com', {'id': 134}],
#  'C1073155388': ['wyattsamantha@example.com', {'id': 135}],
#  'C1073865173': ['orobinson@example.net', {'id': 136}],
#  'C1074203200': ['qmorris@example.com', {'id': 137}],
#  'C107438779': ['jason67@example.org', {'id': 138}],
#  'C10745331': ['hernandezmelissa@example.net', {'id': 139}],
#  'C1075692577': ['brandiblack@example.org', {'id': 140}],
#  'C1075787773': ['powellpatricia@example.net', {'id': 141}],
#  'C1076053396': ['williamsjohn@example.org', {'id': 142}],
#  'C1076110991': ['edodson@example.org', {'id': 143}],
#  'C1077245673': ['ogibson@example.net', {'id': 144}],
#  'C1078316853': ['lopezjohn@example.org', {'id': 145}],
#  'C1078351181': ['samueljohnson@example.com', {'id': 146}],
#  'C1078596280': ['lsmith@example.com', {'id': 147}],
#  'C1078619612': ['sanfordlisa@example.org', {'id': 148}],
#  'C1079254393': ['thomashall@example.org', {'id': 149}],
#  'C1079965849': ['tracy97@example.com', {'id': 150}],
#  'C1080032135': ['chelsea58@example.com', {'id': 151}],
#  'C1080719046': ['carl63@example.org', {'id': 152}],
#  'C1080813886': ['leelisa@example.org', {'id': 153}],
#  'C1081618305': ['fcollins@example.org', {'id': 154}],
#  'C1081944543': ['jamesfarmer@example.com', {'id': 155}],
#  'C1082462651': ['linda30@example.net', {'id': 156}],
#  'C1082594377': ['jeffrey01@example.com', {'id': 157}],
#  'C1082608644': ['ylynn@example.com', {'id': 158}],
#  'C108266856': ['rreilly@example.com', {'id': 159}],
#  'C1082732879': ['stephensondaniel@example.net', {'id': 160}],
#  'C1083375349': ['speterson@example.com', {'id': 161}],
#  'C1083859927': ['kevin07@example.com', {'id': 162}],
#  'C1084001812': ['lisa37@example.com', {'id': 163}],
#  'C1084672760': ['jeffreyolson@example.net', {'id': 164}],
#  'C1085056650': ['krodriguez@example.org', {'id': 165}],
#  'C1085689043': ['eturner@example.org', {'id': 166}],
#  'C1086957388': ['dwilliams@example.org', {'id': 167}],
#  'C1087227796': ['cassandragross@example.com', {'id': 168}],
#  'C1087747329': ['seanwhite@example.net', {'id': 169}],
#  'C1087788850': ['alexandriawilson@example.net', {'id': 170}],
#  'C1087943403': ['vgrant@example.net', {'id': 171}],
#  'C108794529': ['deborahmann@example.net', {'id': 172}],
#  'C1088464518': ['robertbriggs@example.org', {'id': 173}],
#  'C1088768738': ['myersrobyn@example.net', {'id': 174}],
#  'C1088853847': ['johnfrank@example.org', {'id': 175}],
#  'C108940648': ['vickiejohnson@example.org', {'id': 176}],
#  'C1089789227': ['jeffreychandler@example.org', {'id': 177}],
#  'C1089848865': ['lukelopez@example.org', {'id': 178}],
#  'C1089903335': ['zacharyhernandez@example.com', {'id': 179}],
#  'C1090046399': ['richardcobb@example.com', {'id': 180}],
#  'C1090528803': ['gdurham@example.com', {'id': 181}],
#  'C1090604904': ['sheilaflores@example.com', {'id': 182}],
#  'C1091680547': ['samuel94@example.com', {'id': 183}],
#  'C1091966081': ['adammeadows@example.org', {'id': 184}],
#  'C1092512638': ['bradleywebb@example.org', {'id': 185}],
#  'C1092769857': ['andersonjacob@example.com', {'id': 186}],
#  'C1093060677': ['changoscar@example.org', {'id': 187}],
#  'C1093826151': ['tjohnson@example.com', {'id': 188}],
#  'C1093842718': ['raystephanie@example.org', {'id': 189}],
#  'C1095087737': ['jennifer61@example.org', {'id': 190}],
#  'C1095241409': ['harrisandrew@example.com', {'id': 191}],
#  'C1095604325': ['robert90@example.com', {'id': 192}],
#  'C1095821033': ['sotomary@example.org', {'id': 193}],
#  'C109617474': ['hsoto@example.com', {'id': 194}],
#  'C109634232': ['jlewis@example.net', {'id': 195}],
#  'C1096642744': ['smithmichael@example.org', {'id': 196}],
#  'C1097812196': ['morgankevin@example.net', {'id': 197}],
#  'C1098012335': ['yharmon@example.com', {'id': 198}],
#  'C1098443227': ['natalieford@example.org', {'id': 199}],
#  'C109947606': ['tammythomas@example.net', {'id': 200}],
#  'C1100053869': ['ryan33@example.net', {'id': 201}],
#  'C1100276718': ['everettjeremy@example.net', {'id': 202}],
#  'C1100289413': ['catherine15@example.org', {'id': 203}],
#  'C1100337763': ['michaelwallace@example.org', {'id': 204}],
#  'C1100361227': ['kjones@example.net', {'id': 205}],
#  'C1100510913': ['tracymiles@example.org', {'id': 206}],
#  'C1100570635': ['jamesturner@example.org', {'id': 207}],
#  'C1101213728': ['hwilkerson@example.com', {'id': 208}],
#  'C1101433185': ['jeffrey15@example.org', {'id': 209}],
#  'C1101633489': ['waltermarsh@example.net', {'id': 210}],
#  'C1101722853': ['jimenezpamela@example.org', {'id': 211}],
#  'C1102156492': ['lmullins@example.net', {'id': 212}],
#  'C1102464953': ['timothyphillips@example.com', {'id': 213}],
#  'C1104044396': ['michelehouston@example.com', {'id': 214}],
#  'C1104967901': ['pattersontiffany@example.org', {'id': 215}],
#  'C1105086283': ['gregoryjackson@example.com', {'id': 216}],
#  'C1107442215': ['brownvanessa@example.com', {'id': 217}],
#  'C1108967401': ['uwagner@example.org', {'id': 218}],
#  'C1110919755': ['reynoldskeith@example.com', {'id': 219}],
#  'C11116138': ['xrivera@example.org', {'id': 220}],
#  'C1114643543': ['tperez@example.net', {'id': 221}],
#  'C1114685649': ['lisanorris@example.net', {'id': 222}],
#  'C111678629': ['brenda51@example.net', {'id': 223}],
#  'C1117294574': ['william48@example.org', {'id': 224}],
#  'C1117403153': ['listacey@example.net', {'id': 225}],
#  'C1118932469': ['jrogers@example.com', {'id': 226}],
#  'C1118984324': ['jameshodge@example.com', {'id': 227}],
#  'C1120165888': ['zcampbell@example.org', {'id': 228}],
#  'C1121327223': ['christinevelazquez@example.com', {'id': 229}],
#  'C1122213892': ['tyler93@example.com', {'id': 230}],
#  'C1122835446': ['kurtcamacho@example.com', {'id': 231}],
#  'C1123042802': ['dillondoris@example.org', {'id': 232}],
#  'C1123627503': ['dodsonmelissa@example.net', {'id': 233}],
#  'C1124449361': ['david42@example.org', {'id': 234}],
#  'C1124718683': ['mary66@example.net', {'id': 235}],
#  'C1125132707': ['rodneypollard@example.com', {'id': 236}],
#  'C1125717761': ['clarkerichard@example.net', {'id': 237}],
#  'C1125832994': ['montgomeryruben@example.com', {'id': 238}],
#  'C1126112663': ['hmiller@example.com', {'id': 239}],
#  'C1126297464': ['lhart@example.com', {'id': 240}],
#  'C1127069069': ['ajohnson@example.net', {'id': 241}],
#  'C1127607634': ['whamilton@example.org', {'id': 242}],
#  'C1127983201': ['phale@example.net', {'id': 243}],
#  'C1128349548': ['pamela69@example.org', {'id': 244}],
#  'C1128965136': ['johnsonjamie@example.org', {'id': 245}],
#  'C1129111658': ['xmartin@example.org', {'id': 246}],
#  'C1129265408': ['guerraanthony@example.com', {'id': 247}],
#  'C1129461636': ['wsanchez@example.com', {'id': 248}],
#  'C1129737137': ['srodriguez@example.org', {'id': 249}],
#  'C1130259702': ['veronica89@example.net', {'id': 250}],
#  'C1130847219': ['yolanda07@example.com', {'id': 251}],
#  'C1131883667': ['haileyphillips@example.com', {'id': 252}],
#  'C1132392725': ['bburton@example.com', {'id': 253}],
#  'C1132565589': ['gregoryray@example.net', {'id': 254}],
#  'C1133298590': ['stacyrodriguez@example.net', {'id': 255}],
#  'C1133451243': ['phillipsaunders@example.net', {'id': 256}],
#  'C1134333439': ['carolinemckinney@example.org', {'id': 257}],
#  'C1134533551': ['dana11@example.com', {'id': 258}],
#  'C1134994937': ['alex31@example.org', {'id': 259}],
#  'C1135201785': ['christopher81@example.net', {'id': 260}],
#  'C1135495199': ['timothyrodriguez@example.net', {'id': 261}],
#  'C1135867657': ['gwilliams@example.net', {'id': 262}],
#  'C1136643517': ['williamsjulie@example.org', {'id': 263}],
#  'C1136761152': ['evansbrittany@example.com', {'id': 264}],
#  'C1136859577': ['coxjonathan@example.com', {'id': 265}],
#  'C1137292670': ['jeremiah45@example.org', {'id': 266}],
#  'C1139909458': ['thomasfigueroa@example.com', {'id': 267}],
#  'C1139944236': ['rparks@example.com', {'id': 268}],
#  'C1140073765': ['hendricksdylan@example.net', {'id': 269}],
#  'C1140809068': ['jaypierce@example.net', {'id': 270}],
#  'C1141481813': ['carlos88@example.com', {'id': 271}],
#  'C1141524074': ['sarah33@example.net', {'id': 272}],
#  'C1141582476': ['desiree21@example.net', {'id': 273}],
#  'C1142118359': ['chad62@example.org', {'id': 274}],
#  'C1142956269': ['jacobyoung@example.com', {'id': 275}],
#  'C1143300850': ['andrew08@example.com', {'id': 276}],
#  'C1143401925': ['doylesteve@example.com', {'id': 277}],
#  'C114388565': ['toddjeff@example.org', {'id': 278}],
#  'C1145304322': ['wrightmary@example.com', {'id': 279}],
#  'C11453786': ['rossevans@example.org', {'id': 280}],
#  'C1146143839': ['margaretjames@example.org', {'id': 281}],
#  'C1147125608': ['franciscoblackwell@example.com', {'id': 282}],
#  'C1148364854': ['davidcastaneda@example.org', {'id': 283}],
#  'C1148771999': ['mirandabraun@example.net', {'id': 284}],
#  'C1148772789': ['washingtondavid@example.com', {'id': 285}],
#  'C1149179033': ['samantha85@example.com', {'id': 286}],
#  'C1149495561': ['thomaskaitlyn@example.org', {'id': 287}],
#  'C114981535': ['ldavis@example.com', {'id': 288}],
#  'C1149893807': ['schmittkeith@example.net', {'id': 289}],
#  'C1150646122': ['jennifer92@example.com', {'id': 290}],
#  'C1151051721': ['christinewatkins@example.com', {'id': 291}],
#  'C1151600429': ['dhill@example.com', {'id': 292}],
#  'C1151799720': ['odavis@example.com', {'id': 293}],
#  'C1152092987': ['morrisonjessica@example.org', {'id': 294}],
#  'C1152356495': ['cooperhenry@example.net', {'id': 295}],
#  'C1153569753': ['osims@example.com', {'id': 296}],
#  'C1153792315': ['kcopeland@example.org', {'id': 297}],
#  'C1153943594': ['andrewsbenjamin@example.org', {'id': 298}],
#  'C1154612561': ['andrewgibson@example.org', {'id': 299}],
#  'C1154631581': ['uflores@example.com', {'id': 300}],
#  'C1155259690': ['hansenerik@example.net', {'id': 301}],
#  'C115540448': ['eclements@example.org', {'id': 302}],
#  'C1155962240': ['mike39@example.com', {'id': 303}],
#  'C115603187': ['katherinemiller@example.net', {'id': 304}],
#  'C1156188729': ['tho@example.net', {'id': 305}],
#  'C1156346576': ['parkerbilly@example.org', {'id': 306}],
#  'C1156399058': ['oconnorbrian@example.net', {'id': 307}],
#  'C1156509589': ['xrobinson@example.com', {'id': 308}],
#  'C1156672988': ['jenniferberry@example.org', {'id': 309}],
#  'C1156745710': ['cheyenne39@example.org', {'id': 310}],
#  'C1156808163': ['samantha20@example.net', {'id': 311}],
#  'C1156885344': ['iboyle@example.org', {'id': 312}],
#  'C1158233054': ['stevenhill@example.com', {'id': 313}],
#  'C1158646143': ['gabriellethomas@example.com', {'id': 314}],
#  'C1158738757': ['stephenmorgan@example.org', {'id': 315}],
#  'C1158875335': ['kwilson@example.com', {'id': 316}],
#  'C1159034982': ['jessicataylor@example.org', {'id': 317}],
#  'C1159406873': ['rsmith@example.org', {'id': 318}],
#  'C115986226': ['amandasimpson@example.net', {'id': 319}],
#  'C1160118068': ['joywoods@example.org', {'id': 320}],
#  'C1160421902': ['jacob72@example.org', {'id': 321}],
#  'C1161671147': ['xstewart@example.net', {'id': 322}],
#  'C1161927918': ['dominguezsandra@example.org', {'id': 323}],
#  'C1161949399': ['ashleyallen@example.org', {'id': 324}],
#  'C1163388474': ['cooleyadrian@example.com', {'id': 325}],
#  'C1163635747': ['rileynicole@example.org', {'id': 326}],
#  'C1163804561': ['wilsonbrian@example.org', {'id': 327}],
#  'C116386695': ['gary59@example.org', {'id': 328}],
#  'C1164613439': ['nguyensusan@example.com', {'id': 329}],
#  'C1165343027': ['greerstephanie@example.net', {'id': 330}],
#  'C1165454845': ['tiffanyhill@example.org', {'id': 331}],
#  'C1166075201': ['carpenterwilliam@example.net', {'id': 332}],
#  'C1166337448': ['jameseric@example.net', {'id': 333}],
#  'C1166355595': ['bonillabilly@example.net', {'id': 334}],
#  'C116665031': ['zbenson@example.com', {'id': 335}],
#  'C1166683343': ['ericahampton@example.org', {'id': 336}],
#  'C1167781928': ['johnsonedward@example.org', {'id': 337}],
#  'C1169655012': ['xroberts@example.net', {'id': 338}],
#  'C1169771418': ['tcole@example.org', {'id': 339}],
#  'C117112395': ['katie46@example.org', {'id': 340}],
#  'C1171394321': ['sararodriguez@example.com', {'id': 341}],
#  'C1171622243': ['kmccarthy@example.org', {'id': 342}],
#  'C1173530601': ['michaelsavage@example.org', {'id': 343}],
#  'C1174105749': ['kgonzalez@example.net', {'id': 344}],
#  'C1174217921': ['zhanna@example.net', {'id': 345}],
#  'C1174416804': ['rwilliams@example.net', {'id': 346}],
#  'C1174735331': ['pnelson@example.com', {'id': 347}],
#  'C1175419672': ['jamesjerry@example.net', {'id': 348}],
#  'C1175684338': ['dmaddox@example.net', {'id': 349}],
#  'C117577408': ['alexdavis@example.net', {'id': 350}],
#  'C1175850429': ['jbell@example.org', {'id': 351}],
#  'C1176114065': ['howardbruce@example.net', {'id': 352}],
#  'C1177396126': ['tevans@example.net', {'id': 353}],
#  'C1177478758': ['williamsemily@example.com', {'id': 354}],
#  'C1178005728': ['sheri48@example.net', {'id': 355}],
#  'C1178726445': ['emily56@example.org', {'id': 356}],
#  'C1179217322': ['vfloyd@example.com', {'id': 357}],
#  'C1179833140': ['matthewgrant@example.org', {'id': 358}],
#  'C1180570487': ['pricecharles@example.org', {'id': 359}],
#  'C1181615831': ['andersonrenee@example.com', {'id': 360}],
#  'C1182534509': ['william71@example.com', {'id': 361}],
#  'C1182825160': ['ggolden@example.net', {'id': 362}],
#  'C118437987': ['sheltonkelly@example.net', {'id': 363}],
#  'C1186894186': ['sarah60@example.com', {'id': 364}],
#  'C1186953291': ['clewis@example.net', {'id': 365}],
#  'C1187353931': ['santanamatthew@example.com', {'id': 366}],
#  'C1187702596': ['earl49@example.com', {'id': 367}],
#  'C1187730955': ['khowell@example.com', {'id': 368}],
#  'C1187799344': ['clowe@example.org', {'id': 369}],
#  'C1187979419': ['vrichmond@example.net', {'id': 370}],
#  'C118836015': ['heatherbarton@example.org', {'id': 371}],
#  'C1188590334': ['anelson@example.net', {'id': 372}],
#  'C1189224644': ['gaysandra@example.org', {'id': 373}],
#  'C1189231170': ['lbaker@example.net', {'id': 374}],
#  'C1189367947': ['samuelpollard@example.com', {'id': 375}],
#  'C1189752912': ['carla29@example.org', {'id': 376}],
#  'C1191069340': ['barnesmaxwell@example.net', {'id': 377}],
#  'C1191796691': ['erogers@example.com', {'id': 378}],
#  'C1191832390': ['poncehoward@example.com', {'id': 379}],
#  'C1192557067': ['john35@example.com', {'id': 380}],
#  'C119274188': ['nhughes@example.org', {'id': 381}],
#  'C1192874833': ['elizabeth60@example.net', {'id': 382}],
#  'C1193034305': ['nancy13@example.net', {'id': 383}],
#  'C1194290880': ['douglas09@example.org', {'id': 384}],
#  'C1194320883': ['jessicajackson@example.net', {'id': 385}],
#  'C119537158': ['mdean@example.net', {'id': 386}],
#  'C1195893546': ['morrisemily@example.org', {'id': 387}],
#  'C1196149230': ['darrell69@example.org', {'id': 388}],
#  'C1196357413': ['katherine73@example.net', {'id': 389}],
#  'C1196579721': ['martinrichard@example.com', {'id': 390}],
#  'C1196808546': ['johnbrown@example.org', {'id': 391}],
#  'C1196915447': ['robert07@example.org', {'id': 392}],
#  'C1197304790': ['stephanie93@example.org', {'id': 393}],
#  'C1199767081': ['andreaadams@example.org', {'id': 394}],
#  'C1199849921': ['ronald54@example.net', {'id': 395}],
#  'C1200227736': ['brandon21@example.com', {'id': 396}],
#  'C1200311106': ['smedina@example.net', {'id': 397}],
#  'C1200336063': ['nathanielrhodes@example.net', {'id': 398}],
#  'C1200798307': ['robertpadilla@example.net', {'id': 399}],
#  'C1201696181': ['glennmartinez@example.org', {'id': 400}],
#  'C1201848792': ['salvarez@example.com', {'id': 401}],
#  'C1202775726': ['mcruz@example.net', {'id': 402}],
#  'C120279480': ['wbennett@example.org', {'id': 403}],
#  'C1202857292': ['bethhill@example.net', {'id': 404}],
#  'C1203244235': ['bakermike@example.org', {'id': 405}],
#  'C1204046804': ['cristinawilliams@example.net', {'id': 406}],
#  'C1204610604': ['kroberts@example.net', {'id': 407}],
#  'C1204740969': ['bradleyjones@example.com', {'id': 408}],
#  'C1204780618': ['jamesalvarez@example.com', {'id': 409}],
#  'C1205257074': ['fwagner@example.org', {'id': 410}],
#  'C1206604144': ['adriennejones@example.net', {'id': 411}],
#  'C120661238': ['jonesjohnny@example.com', {'id': 412}],
#  'C1207205377': ['xhill@example.com', {'id': 413}],
#  'C1207877529': ['gregorywright@example.org', {'id': 414}],
#  'C1207935724': ['denisegeorge@example.com', {'id': 415}],
#  'C1208123566': ['jacobsamy@example.com', {'id': 416}],
#  'C1209363182': ['eatonmary@example.org', {'id': 417}],
#  'C1209651258': ['riverakaitlyn@example.org', {'id': 418}],
#  'C1209743372': ['tracy38@example.net', {'id': 419}],
#  'C1209838312': ['jlee@example.com', {'id': 420}],
#  'C1210957250': ['chandlermario@example.org', {'id': 421}],
#  'C1211514218': ['veronicafranklin@example.net', {'id': 422}],
#  'C1212956427': ['cmontes@example.net', {'id': 423}],
#  'C1213002113': ['kellyjohnson@example.net', {'id': 424}],
#  'C1213984358': ['stevenwheeler@example.com', {'id': 425}],
#  'C1214229415': ['ahooper@example.net', {'id': 426}],
#  'C1214279601': ['lpowers@example.net', {'id': 427}],
#  'C1214582637': ['tonya32@example.org', {'id': 428}],
#  'C1214587699': ['bob17@example.org', {'id': 429}],
#  'C1214628974': ['mathew14@example.org', {'id': 430}],
#  'C1214780453': ['ricardoreynolds@example.com', {'id': 431}],
#  'C1214826221': ['qrangel@example.org', {'id': 432}],
#  'C1214828746': ['wallen@example.org', {'id': 433}],
#  'C1214929092': ['howellcolleen@example.com', {'id': 434}],
#  'C1214964999': ['grayjames@example.com', {'id': 435}],
#  'C1215468370': ['asantos@example.com', {'id': 436}],
#  'C1216409727': ['patrickgarcia@example.net', {'id': 437}],
#  'C1216867117': ['maldonadoabigail@example.org', {'id': 438}],
#  'C1216919532': ['ebutler@example.net', {'id': 439}],
#  'C121713128': ['brownlaura@example.org', {'id': 440}],
#  'C121798652': ['lisa25@example.org', {'id': 441}],
#  'C1221114448': ['melindaevans@example.org', {'id': 442}],
#  'C1222389110': ['emiller@example.net', {'id': 443}],
#  'C122290547': ['regina94@example.net', {'id': 444}],
#  'C1223439629': ['julie21@example.com', {'id': 445}],
#  'C1224153830': ['christopherbullock@example.net', {'id': 446}],
#  'C1224222502': ['melissa69@example.com', {'id': 447}],
#  'C1225533078': ['stephanie48@example.com', {'id': 448}],
#  'C1225704566': ['zavalachloe@example.net', {'id': 449}],
#  'C1225717157': ['herreralatoya@example.net', {'id': 450}],
#  'C1226558289': ['rachel41@example.net', {'id': 451}],
#  'C1226947303': ['hensonlynn@example.com', {'id': 452}],
#  'C1227773968': ['wjones@example.org', {'id': 453}],
#  'C1228152586': ['tfrancis@example.com', {'id': 454}],
#  'C1228157206': ['ucummings@example.com', {'id': 455}],
#  'C12284077': ['anneharris@example.net', {'id': 456}],
#  'C1229072215': ['connie89@example.net', {'id': 457}],
#  'C1229114783': ['andrew37@example.net', {'id': 458}],
#  'C1229674572': ['davidharmon@example.com', {'id': 459}],
#  'C1230747575': ['leonardscott@example.net', {'id': 460}],
#  'C1231572628': ['james11@example.com', {'id': 461}],
#  'C1232356156': ['cli@example.net', {'id': 462}],
#  'C1232523772': ['webbjeffery@example.net', {'id': 463}],
#  'C1232725180': ['warrenelizabeth@example.org', {'id': 464}],
#  'C1233238493': ['shanejohnson@example.org', {'id': 465}],
#  'C123366357': ['brittneybryant@example.org', {'id': 466}],
#  'C1233802034': ['brownvanessa@example.org', {'id': 467}],
#  'C1233811793': ['ygriffith@example.com', {'id': 468}],
#  'C1234264195': ['jennifer96@example.net', {'id': 469}],
#  'C1234470601': ['seth36@example.org', {'id': 470}],
#  'C1235359960': ['fernando78@example.com', {'id': 471}],
#  'C123623130': ['wnixon@example.com', {'id': 472}],
#  'C1236489588': ['susanharris@example.com', {'id': 473}],
#  'C1236503001': ['robertsnicholas@example.net', {'id': 474}],
#  'C1236509536': ['rhunter@example.com', {'id': 475}],
#  'C1237272991': ['atownsend@example.org', {'id': 476}],
#  'C1237476993': ['kruegergerald@example.net', {'id': 477}],
#  'C1237709469': ['jenniferbradley@example.com', {'id': 478}],
#  'C1238185596': ['moralesraven@example.com', {'id': 479}],
#  'C1238755034': ['jthomas@example.com', {'id': 480}],
#  'C1238891395': ['kylemooney@example.net', {'id': 481}],
#  'C1239061472': ['noahduke@example.com', {'id': 482}],
#  'C1240209240': ['brooksdylan@example.org', {'id': 483}],
#  'C1240560903': ['robertkeller@example.net', {'id': 484}],
#  'C1240746302': ['adavis@example.com', {'id': 485}],
#  'C1242334684': ['amy21@example.net', {'id': 486}],
#  'C1242643189': ['hilljennifer@example.org', {'id': 487}],
#  'C1242686524': ['donovanthomas@example.net', {'id': 488}],
#  'C1245363669': ['stefanie61@example.com', {'id': 489}],
#  'C124539163': ['jhill@example.org', {'id': 490}],
#  'C1246760376': ['kennedykaren@example.org', {'id': 491}],
#  'C1248026439': ['olsonheather@example.com', {'id': 492}],
#  'C1248053373': ['vcooke@example.com', {'id': 493}],
#  'C1249070059': ['mcohen@example.net', {'id': 494}],
#  'C1249352100': ['suzanne18@example.net', {'id': 495}],
#  'C1249817283': ['bobbyhumphrey@example.org', {'id': 496}],
#  'C125143024': ['kennethdawson@example.net', {'id': 497}],
#  'C1251749294': ['zachary24@example.net', {'id': 498}],
#  'C1253245889': ['wilsonryan@example.org', {'id': 499}],
#  'C1253760419': ['aaron22@example.org', {'id': 500}],
#  'C1254064510': ['zmurphy@example.net', {'id': 501}],
#  'C1254696728': ['lpeterson@example.net', {'id': 502}],
#  'C125481968': ['margaret85@example.org', {'id': 503}],
#  'C1255149927': ['nhall@example.com', {'id': 504}],
#  'C1255221015': ['franktimothy@example.net', {'id': 505}],
#  'C1255231772': ['howelldonald@example.com', {'id': 506}],
#  'C1255236689': ['mberry@example.org', {'id': 507}],
#  'C1255643141': ['jameschristopher@example.com', {'id': 508}],
#  'C1256072323': ['jessica44@example.net', {'id': 509}],
#  'C1256073744': ['patrickhill@example.org', {'id': 510}],
#  'C1256908044': ['andersonjaclyn@example.com', {'id': 511}],
#  'C1257820473': ['berryjimmy@example.com', {'id': 512}],
#  'C1258211852': ['wernermark@example.com', {'id': 513}],
#  'C1258454385': ['gtorres@example.org', {'id': 514}],
#  'C1258725927': ['linda87@example.net', {'id': 515}],
#  'C1258953485': ['johnsonmatthew@example.org', {'id': 516}],
#  'C1259046770': ['david82@example.org', {'id': 517}],
#  'C1259389151': ['megancarr@example.org', {'id': 518}],
#  'C1259760240': ['npitts@example.net', {'id': 519}],
#  'C1261640227': ['jonesjohn@example.org', {'id': 520}],
#  'C1262879702': ['wintersdevin@example.net', {'id': 521}],
#  'C1263107170': ['gbaker@example.com', {'id': 522}],
#  'C1263267362': ['oflores@example.org', {'id': 523}],
#  'C1263461120': ['rmiller@example.org', {'id': 524}],
#  'C1264224372': ['benjaminbrown@example.org', {'id': 525}],
#  'C1264836741': ['turnermichael@example.com', {'id': 526}],
#  'C126488680': ['dwright@example.org', {'id': 527}],
#  'C126603077': ['mcollier@example.com', {'id': 528}],
#  'C12662072': ['pachecomelanie@example.com', {'id': 529}],
#  'C1266329800': ['moyerjerry@example.com', {'id': 530}],
#  'C126638730': ['htaylor@example.org', {'id': 531}],
#  'C1267365709': ['timothybutler@example.org', {'id': 532}],
#  'C1267444276': ['nroberts@example.org', {'id': 533}],
#  'C1267749701': ['emma41@example.org', {'id': 534}],
#  'C1267913176': ['jessicalucas@example.org', {'id': 535}],
#  'C1268275182': ['williamsjean@example.net', {'id': 536}],
#  'C1269217373': ['jonestabitha@example.org', {'id': 537}],
#  'C1269288419': ['stacey30@example.net', {'id': 538}],
#  'C1269635185': ['larry21@example.net', {'id': 539}],
#  'C1271484467': ['wheelernicole@example.net', {'id': 540}],
#  'C1272188168': ['eric60@example.net', {'id': 541}],
#  'C1272326382': ['karen07@example.org', {'id': 542}],
#  'C1273015960': ['popelisa@example.org', {'id': 543}],
#  'C1273110804': ['misty73@example.com', {'id': 544}],
#  'C1273564839': ['larabrandon@example.org', {'id': 545}],
#  'C1273692645': ['jennifermartinez@example.com', {'id': 546}],
#  'C1273885837': ['dennis00@example.org', {'id': 547}],
#  'C1274818444': ['thaynes@example.org', {'id': 548}],
#  'C1275053057': ['rsaunders@example.com', {'id': 549}],
#  'C1275518867': ['shelbygrant@example.net', {'id': 550}],
#  'C1275741147': ['randy94@example.org', {'id': 551}],
#  'C1276892406': ['zhernandez@example.net', {'id': 552}],
#  'C1278181986': ['mmelendez@example.net', {'id': 553}],
#  'C1279143519': ['amywallace@example.net', {'id': 554}],
#  'C1279668658': ['christopherstrickland@example.com', {'id': 555}],
#  'C1279785305': ['vegajames@example.net', {'id': 556}],
#  'C128008012': ['moralesgeorge@example.net', {'id': 557}],
#  'C1280960686': ['zacharypadilla@example.com', {'id': 558}],
#  'C1281345721': ['awilcox@example.com', {'id': 559}],
#  'C1282114843': ['qortiz@example.net', {'id': 560}],
#  'C1282333137': ['ronald04@example.org', {'id': 561}],
#  'C1282628311': ['robertsolis@example.com', {'id': 562}],
#  'C1283534588': ['zachary48@example.com', {'id': 563}],
#  'C1284327050': ['ohenderson@example.org', {'id': 564}],
#  'C1284515419': ['ljohnson@example.org', {'id': 565}],
#  'C1285086629': ['jacksonnicole@example.net', {'id': 566}],
#  'C1287167517': ['thomas61@example.com', {'id': 567}],
#  'C128812892': ['colemanrobin@example.com', {'id': 568}],
#  'C1288983259': ['christopher29@example.org', {'id': 569}],
#  'C1289081546': ['powelljeffrey@example.org', {'id': 570}],
#  'C1289219178': ['vking@example.net', {'id': 571}],
#  'C1289997724': ['penny32@example.com', {'id': 572}],
#  'C1290093162': ['renee42@example.com', {'id': 573}],
#  'C1292140369': ['gabriellerobinson@example.com', {'id': 574}],
#  'C1292770722': ['suzanneraymond@example.org', {'id': 575}],
#  'C1293338142': ['darlene83@example.net', {'id': 576}],
#  'C1293579037': ['henrysarah@example.org', {'id': 577}],
#  'C129386345': ['bowersjames@example.net', {'id': 578}],
#  'C1294166760': ['john38@example.com', {'id': 579}],
#  'C1295444668': ['nelsonerin@example.com', {'id': 580}],
#  'C129566217': ['jlawrence@example.com', {'id': 581}],
#  'C1295945354': ['bethalvarado@example.net', {'id': 582}],
#  'C1296664552': ['nguyenkatelyn@example.com', {'id': 583}],
#  'C1297100897': ['wfischer@example.com', {'id': 584}],
#  'C1297358265': ['heather36@example.org', {'id': 585}],
#  'C1297995542': ['perezloretta@example.com', {'id': 586}],
#  'C1298891864': ['gmartin@example.com', {'id': 587}],
#  'C1299279378': ['holtaustin@example.net', {'id': 588}],
#  'C1299368401': ['kimberlyrogers@example.com', {'id': 589}],
#  'C1299474405': ['oestrada@example.org', {'id': 590}],
#  'C1299496226': ['ashley60@example.org', {'id': 591}],
#  'C1299745394': ['shane00@example.net', {'id': 592}],
#  'C130295904': ['gonzaleznicholas@example.com', {'id': 593}],
#  'C1303226190': ['jenniferoconnor@example.com', {'id': 594}],
#  'C1303555047': ['scottpaul@example.net', {'id': 595}],
#  'C1303695653': ['kim34@example.com', {'id': 596}],
#  'C1303935849': ['joshua67@example.net', {'id': 597}],
#  'C1304285526': ['daniel88@example.com', {'id': 598}],
#  'C1304286493': ['danielward@example.org', {'id': 599}],
#  'C1304621872': ['carrbrian@example.org', {'id': 600}],
#  'C1305161735': ['samantha95@example.net', {'id': 601}],
#  'C1305339250': ['julierobinson@example.net', {'id': 602}],
#  'C1306889886': ['melindasmith@example.org', {'id': 603}],
#  'C1307336396': ['znorris@example.org', {'id': 604}],
#  'C1307916597': ['codymoore@example.net', {'id': 605}],
#  'C1308910127': ['josephdelgado@example.net', {'id': 606}],
#  'C1309027409': ['vgarrett@example.net', {'id': 607}],
#  'C1309194397': ['gilbertalexander@example.net', {'id': 608}],
#  'C1309403692': ['margaretwoodard@example.com', {'id': 609}],
#  'C130979586': ['aprilhuff@example.com', {'id': 610}],
#  'C13098029': ['michelegarcia@example.com', {'id': 611}],
#  'C1311947724': ['ortiztammy@example.org', {'id': 612}],
#  'C131200254': ['jessica76@example.com', {'id': 613}],
#  'C1312448128': ['daniellethompson@example.net', {'id': 614}],
#  'C1312615175': ['ydougherty@example.com', {'id': 615}],
#  'C131296547': ['angela41@example.com', {'id': 616}],
#  'C1313060996': ['psoto@example.org', {'id': 617}],
#  'C1314174420': ['kendracastillo@example.net', {'id': 618}],
#  'C1314533733': ['kinghunter@example.com', {'id': 619}],
#  'C1314685160': ['lindseyjordan@example.net', {'id': 620}],
#  'C1315400589': ['william77@example.org', {'id': 621}],
#  'C131559770': ['kimcaleb@example.net', {'id': 622}],
#  'C1316160034': ['gouldjesus@example.com', {'id': 623}],
#  'C1316262830': ['brandon43@example.net', {'id': 624}],
#  'C131682780': ['john49@example.net', {'id': 625}],
#  'C1316936887': ['adamsjohnathan@example.org', {'id': 626}],
#  'C1317710133': ['laneerin@example.org', {'id': 627}],
#  'C131915922': ['yhernandez@example.org', {'id': 628}],
#  'C1319350044': ['michelle71@example.com', {'id': 629}],
#  'C1320066686': ['vbennett@example.org', {'id': 630}],
#  'C1320820565': ['stephanieparker@example.com', {'id': 631}],
#  'C1321173882': ['peggybuchanan@example.net', {'id': 632}],
#  'C1321650743': ['davisbrenda@example.org', {'id': 633}],
#  'C1321889892': ['amanda09@example.org', {'id': 634}],
#  'C132320296': ['qholmes@example.net', {'id': 635}],
#  'C132392875': ['ericpierce@example.com', {'id': 636}],
#  'C1324001180': ['dmacias@example.org', {'id': 637}],
#  'C132520837': ['yjohnson@example.org', {'id': 638}],
#  'C1325422547': ['michael52@example.com', {'id': 639}],
#  'C1325638360': ['francomichael@example.com', {'id': 640}],
#  'C1326593353': ['samantha07@example.com', {'id': 641}],
#  'C1327124397': ['joshuarosario@example.net', {'id': 642}],
#  'C1327677398': ['gmiller@example.org', {'id': 643}],
#  'C1329920992': ['joshua41@example.com', {'id': 644}],
#  'C1331907286': ['hawkinstammy@example.net', {'id': 645}],
#  'C1332125345': ['amanda16@example.com', {'id': 646}],
#  'C1332295774': ['janicethompson@example.com', {'id': 647}],
#  'C1333401746': ['ygraham@example.com', {'id': 648}],
#  'C1333537680': ['fbanks@example.com', {'id': 649}],
#  'C1333661820': ['michael33@example.com', {'id': 650}],
#  'C133401060': ['durhamjoseph@example.org', {'id': 651}],
#  'C1334045764': ['tabithahoward@example.org', {'id': 652}],
#  'C1334227305': ['abigail62@example.com', {'id': 653}],
#  'C133432771': ['virginiahamilton@example.net', {'id': 654}],
#  'C1334695551': ['jillian42@example.org', {'id': 655}],
#  'C1335108214': ['samantha16@example.net', {'id': 656}],
#  'C1336232196': ['grahamsharon@example.net', {'id': 657}],
#  'C1337135199': ['linda17@example.net', {'id': 658}],
#  'C133764711': ['tanya65@example.com', {'id': 659}],
#  'C1337923906': ['jasoncarlson@example.com', {'id': 660}],
#  'C1337948674': ['gregg79@example.net', {'id': 661}],
#  'C1338020899': ['jodyjones@example.org', {'id': 662}],
#  'C1338125837': ['dthompson@example.org', {'id': 663}],
#  'C1338396147': ['timothychavez@example.com', {'id': 664}],
#  'C1338727022': ['crystalholland@example.net', {'id': 665}],
#  'C1338932459': ['amanda18@example.net', {'id': 666}],
#  'C1339724832': ['mlyons@example.com', {'id': 667}],
#  'C1340235335': ['theresarodriguez@example.com', {'id': 668}],
#  'C1340398290': ['joseph29@example.org', {'id': 669}],
#  'C1341517098': ['margaret69@example.com', {'id': 670}],
#  'C1341583263': ['castrojason@example.net', {'id': 671}],
#  'C1341662543': ['kevinrojas@example.net', {'id': 672}],
#  'C1342037956': ['sknight@example.com', {'id': 673}],
#  'C1342118588': ['anthony52@example.org', {'id': 674}],
#  'C1342849651': ['campbellbenjamin@example.org', {'id': 675}],
#  'C1343106500': ['walkerheather@example.net', {'id': 676}],
#  'C1344489848': ['njenkins@example.org', {'id': 677}],
#  'C1345265337': ['kristin16@example.org', {'id': 678}],
#  'C1346358504': ['nwright@example.com', {'id': 679}],
#  'C1347371891': ['robert70@example.org', {'id': 680}],
#  'C1348847019': ['briangallegos@example.com', {'id': 681}],
#  'C1348957967': ['oalexander@example.com', {'id': 682}],
#  'C1349086787': ['michael44@example.com', {'id': 683}],
#  'C1349106433': ['martinlucas@example.org', {'id': 684}],
#  'C1349321790': ['deborahdougherty@example.net', {'id': 685}],
#  'C1350068848': ['oneillmatthew@example.org', {'id': 686}],
#  'C1350082938': ['hcooper@example.net', {'id': 687}],
#  'C1350409226': ['cellis@example.org', {'id': 688}],
#  'C1350793893': ['kristen62@example.org', {'id': 689}],
#  'C1350963410': ['stacey42@example.org', {'id': 690}],
#  'C1351087312': ['michael66@example.org', {'id': 691}],
#  'C1352750459': ['hudsontina@example.org', {'id': 692}],
#  'C1353625448': ['yhopkins@example.com', {'id': 693}],
#  'C1353776547': ['april91@example.com', {'id': 694}],
#  'C1354206365': ['bbarnes@example.com', {'id': 695}],
#  'C135434041': ['qhunt@example.org', {'id': 696}],
#  'C1354768768': ['alyssajohnston@example.org', {'id': 697}],
#  'C1354799046': ['beverly66@example.com', {'id': 698}],
#  'C1354917220': ['tamarakaufman@example.net', {'id': 699}],
#  'C1355010178': ['dawn65@example.net', {'id': 700}],
#  'C1355090926': ['michaelgarcia@example.org', {'id': 701}],
#  'C1355273346': ['patricia77@example.net', {'id': 702}],
#  'C1355357191': ['fosterchase@example.org', {'id': 703}],
#  'C1355509614': ['hickmanapril@example.org', {'id': 704}],
#  'C1356412685': ['jessica83@example.org', {'id': 705}],
#  'C135716487': ['scott90@example.com', {'id': 706}],
#  'C1358079072': ['tracyblankenship@example.org', {'id': 707}],
#  'C1358225719': ['garciakelly@example.net', {'id': 708}],
#  'C1359606474': ['jason34@example.net', {'id': 709}],
#  'C1360225709': ['mbaker@example.org', {'id': 710}],
#  'C1360265061': ['vgarcia@example.com', {'id': 711}],
#  'C1360481565': ['johnsonlinda@example.com', {'id': 712}],
#  'C1361037703': ['apoole@example.org', {'id': 713}],
#  'C1361248894': ['mary83@example.com', {'id': 714}],
#  'C1362652272': ['kaylagonzales@example.org', {'id': 715}],
#  'C1362863442': ['dale20@example.com', {'id': 716}],
#  'C1364381627': ['lewisrebecca@example.net', {'id': 717}],
#  'C1365609574': ['youngronald@example.org', {'id': 718}],
#  'C136606306': ['victoria18@example.com', {'id': 719}],
#  'C1366869967': ['uthomas@example.net', {'id': 720}],
#  'C1367581052': ['rjackson@example.org', {'id': 721}],
#  'C1367987964': ['wayneowens@example.org', {'id': 722}],
#  'C1368070837': ['bartonchristina@example.org', {'id': 723}],
#  'C1368210201': ['wyatt59@example.org', {'id': 724}],
#  'C1368438034': ['dburns@example.net', {'id': 725}],
#  'C1369559766': ['eric92@example.com', {'id': 726}],
#  'C1370192017': ['hernandezcaitlin@example.com', {'id': 727}],
#  'C1370556911': ['brady38@example.com', {'id': 728}],
#  'C1370669821': ['christopher85@example.org', {'id': 729}],
#  'C1372889664': ['dclark@example.net', {'id': 730}],
#  'C1373640509': ['sophia83@example.org', {'id': 731}],
#  'C1373973501': ['tammy62@example.net', {'id': 732}],
#  'C1374011975': ['griffinscott@example.com', {'id': 733}],
#  'C1374336520': ['matamegan@example.net', {'id': 734}],
#  'C1374422827': ['tylercampbell@example.net', {'id': 735}],
#  'C1374783350': ['brian67@example.org', {'id': 736}],
#  'C1375103798': ['candice99@example.net', {'id': 737}],
#  'C1375316332': ['michaelcasey@example.com', {'id': 738}],
#  'C1375512856': ['amberallen@example.net', {'id': 739}],
#  'C1375956198': ['grobinson@example.org', {'id': 740}],
#  'C1376050027': ['stokesshawn@example.com', {'id': 741}],
#  'C1376256048': ['bradsilva@example.net', {'id': 742}],
#  'C1376617526': ['carriegarcia@example.net', {'id': 743}],
#  'C1376957295': ['cheyenne17@example.com', {'id': 744}],
#  'C1377339988': ['xsutton@example.net', {'id': 745}],
#  'C1377736719': ['garyorr@example.com', {'id': 746}],
#  'C1378412230': ['gina97@example.org', {'id': 747}],
#  'C1379018843': ['smithdorothy@example.com', {'id': 748}],
#  'C1379814778': ['sloancraig@example.org', {'id': 749}],
#  'C137986193': ['ojones@example.org', {'id': 750}],
#  'C1381700589': ['darryl61@example.org', {'id': 751}],
#  'C1382187685': ['matthewgarcia@example.org', {'id': 752}],
#  'C1382480007': ['michaelbest@example.net', {'id': 753}],
#  'C1383269171': ['briggsjames@example.com', {'id': 754}],
#  'C1383337902': ['austinzimmerman@example.net', {'id': 755}],
#  'C138375181': ['mjones@example.org', {'id': 756}],
#  'C138445718': ['ashleyprice@example.net', {'id': 757}],
#  'C1385115265': ['pobrien@example.net', {'id': 758}],
#  'C1385354747': ['hobbsmichael@example.net', {'id': 759}],
#  'C1385406679': ['adamlloyd@example.com', {'id': 760}],
#  'C1385780363': ['odelgado@example.net', {'id': 761}],
#  'C1386324281': ['richardmartinez@example.com', {'id': 762}],
#  'C1387070447': ['fmartin@example.org', {'id': 763}],
#  'C1387946894': ['whitemelissa@example.org', {'id': 764}],
#  'C1388726904': ['vbrown@example.net', {'id': 765}],
#  'C1388933025': ['porterduane@example.net', {'id': 766}],
#  'C1389003663': ['fjefferson@example.org', {'id': 767}],
#  'C1389188684': ['hrivera@example.net', {'id': 768}],
#  'C1389311354': ['ypowell@example.net', {'id': 769}],
#  'C1389923471': ['shirley38@example.net', {'id': 770}],
#  'C1390331883': ['steeleapril@example.net', {'id': 771}],
#  'C1392385769': ['turnereric@example.com', {'id': 772}],
#  'C1394428191': ['thompsonbrittney@example.com', {'id': 773}],
#  'C1394454342': ['scottkane@example.com', {'id': 774}],
#  'C1394931354': ['sanchezcatherine@example.org', {'id': 775}],
#  'C1395098424': ['jenniferhernandez@example.net', {'id': 776}],
#  'C1396527012': ['james42@example.net', {'id': 777}],
#  'C1396720108': ['rdyer@example.net', {'id': 778}],
#  'C1396904959': ['donald32@example.com', {'id': 779}],
#  'C1396978257': ['vwilson@example.net', {'id': 780}],
#  'C1397554341': ['osbornerobert@example.com', {'id': 781}],
#  'C139784508': ['emilygrant@example.org', {'id': 782}],
#  'C1398865038': ['oanderson@example.org', {'id': 783}],
#  'C1400397779': ['katieolson@example.org', {'id': 784}],
#  'C1400578246': ['brenda29@example.org', {'id': 785}],
#  'C1401244511': ['amy32@example.org', {'id': 786}],
#  'C1402203755': ['plam@example.com', {'id': 787}],
#  'C140234280': ['candrews@example.net', {'id': 788}],
#  'C1402369177': ['charlesaustin@example.org', {'id': 789}],
#  'C1402381285': ['mgreen@example.com', {'id': 790}],
#  'C1403689550': ['scott12@example.org', {'id': 791}],
#  'C1404589205': ['sandra20@example.com', {'id': 792}],
#  'C1404684380': ['ejohnson@example.com', {'id': 793}],
#  'C1405664150': ['glenda90@example.net', {'id': 794}],
#  'C140648396': ['joshua40@example.com', {'id': 795}],
#  'C1407087523': ['hansensteve@example.net', {'id': 796}],
#  'C1407767965': ['harrisonparker@example.net', {'id': 797}],
#  'C140804810': ['lisa46@example.org', {'id': 798}],
#  'C1408489165': ['martinezjeremy@example.com', {'id': 799}],
#  'C1409858085': ['bsmith@example.com', {'id': 800}],
#  'C1410823375': ['leebenjamin@example.org', {'id': 801}],
#  'C1411169363': ['elizabeth93@example.com', {'id': 802}],
#  'C1412753123': ['spencersarah@example.org', {'id': 803}],
#  'C1413412440': ['gregoryhuffman@example.com', {'id': 804}],
#  'C1413774656': ['mwilliams@example.org', {'id': 805}],
#  'C1414112698': ['theresa01@example.com', {'id': 806}],
#  'C1414374774': ['iwiggins@example.com', {'id': 807}],
#  'C1415168453': ['kathleen83@example.net', {'id': 808}],
#  'C1415453492': ['cpruitt@example.org', {'id': 809}],
#  'C1415571957': ['bridgesjames@example.net', {'id': 810}],
#  'C1415704373': ['millerrick@example.org', {'id': 811}],
#  'C1415998962': ['teresablevins@example.org', {'id': 812}],
#  'C1416816772': ['juan02@example.org', {'id': 813}],
#  'C1417312384': ['vowen@example.com', {'id': 814}],
#  'C1418055040': ['stephanieallen@example.com', {'id': 815}],
#  'C1418322275': ['bnelson@example.org', {'id': 816}],
#  'C1419235351': ['alexandermartinez@example.org', {'id': 817}],
#  'C1419246450': ['xrobbins@example.org', {'id': 818}],
#  'C1420354861': ['joselynn@example.com', {'id': 819}],
#  'C1420603517': ['jschroeder@example.net', {'id': 820}],
#  'C1421006824': ['miakhan@example.net', {'id': 821}],
#  'C1421601814': ['garciatina@example.com', {'id': 822}],
#  'C1422393615': ['ijames@example.org', {'id': 823}],
#  'C142251484': ['johnsonjill@example.net', {'id': 824}],
#  'C1423519115': ['marshallmiranda@example.com', {'id': 825}],
#  'C1423644375': ['terrance78@example.net', {'id': 826}],
#  'C1423828273': ['hmoore@example.com', {'id': 827}],
#  'C1424007721': ['pharrell@example.com', {'id': 828}],
#  'C1424475955': ['hcox@example.net', {'id': 829}],
#  'C1425441042': ['kbrown@example.org', {'id': 830}],
#  'C1425719203': ['ryanhall@example.com', {'id': 831}],
#  'C142595093': ['wrollins@example.org', {'id': 832}],
#  'C1426006139': ['vdavis@example.net', {'id': 833}],
#  'C1426091756': ['masonmichael@example.net', {'id': 834}],
#  'C1426420214': ['rodriguezdeborah@example.org', {'id': 835}],
#  'C1427325535': ['mrice@example.org', {'id': 836}],
#  'C1427539236': ['trevorfranklin@example.net', {'id': 837}],
#  'C1428252955': ['vjenkins@example.net', {'id': 838}],
#  'C1429394820': ['scottkevin@example.net', {'id': 839}],
#  'C1431362064': ['kristendecker@example.com', {'id': 840}],
#  'C1431806998': ['terrigutierrez@example.net', {'id': 841}],
#  'C1432312197': ['sarahhawkins@example.org', {'id': 842}],
#  'C1432825682': ['brenda25@example.org', {'id': 843}],
#  'C1433092877': ['martinezsusan@example.net', {'id': 844}],
#  'C1433132752': ['tjones@example.net', {'id': 845}],
#  'C1433318702': ['matthew58@example.org', {'id': 846}],
#  'C1433843082': ['ortegabrandon@example.com', {'id': 847}],
#  'C1434797923': ['dgallagher@example.org', {'id': 848}],
#  'C1434853621': ['wallsjennifer@example.com', {'id': 849}],
#  'C143498560': ['hstanley@example.net', {'id': 850}],
#  'C1435043122': ['slittle@example.com', {'id': 851}],
#  'C1435256152': ['zbennett@example.net', {'id': 852}],
#  'C1435653171': ['eric51@example.org', {'id': 853}],
#  'C1436301390': ['wgreen@example.com', {'id': 854}],
#  'C1436756684': ['adrian55@example.net', {'id': 855}],
#  'C1437099450': ['kimberly74@example.org', {'id': 856}],
#  'C1437990673': ['melissa93@example.com', {'id': 857}],
#  'C143836998': ['fjones@example.com', {'id': 858}],
#  'C1438489717': ['samanthawhite@example.org', {'id': 859}],
#  'C1439299369': ['sharprobert@example.org', {'id': 860}],
#  'C1439470393': ['robert89@example.net', {'id': 861}],
#  'C1439880421': ['guerrabrittany@example.com', {'id': 862}],
#  'C1440310601': ['david50@example.net', {'id': 863}],
#  'C1440340988': ['corydavis@example.net', {'id': 864}],
#  'C1440755608': ['xgray@example.net', {'id': 865}],
#  'C1440811710': ['angelalawson@example.org', {'id': 866}],
#  'C1441133487': ['imiller@example.net', {'id': 867}],
#  'C1445784416': ['anthonymorales@example.com', {'id': 868}],
#  'C1445931696': ['smithguy@example.org', {'id': 869}],
#  'C1446511647': ['nsmith@example.org', {'id': 870}],
#  'C144783459': ['apriljohnson@example.net', {'id': 871}],
#  'C144835944': ['richardsonmark@example.com', {'id': 872}],
#  'C1449000407': ['gpatterson@example.net', {'id': 873}],
#  'C1450140987': ['thomasbenjamin@example.net', {'id': 874}],
#  'C1450354557': ['atkinsvictoria@example.net', {'id': 875}],
#  'C1450562088': ['hrichards@example.org', {'id': 876}],
#  'C1451561221': ['gainesmatthew@example.org', {'id': 877}],
#  'C1452020181': ['chloe20@example.com', {'id': 878}],
#  'C1452053500': ['aaron17@example.org', {'id': 879}],
#  'C145208657': ['amartinez@example.com', {'id': 880}],
#  'C145230032': ['hannah57@example.com', {'id': 881}],
#  'C1452354279': ['dawnthomas@example.org', {'id': 882}],
#  'C1452504275': ['adrienne59@example.org', {'id': 883}],
#  'C1453275851': ['annmccormick@example.com', {'id': 884}],
#  'C1453715655': ['carrolljeanette@example.net', {'id': 885}],
#  'C1453917071': ['matthewmiller@example.org', {'id': 886}],
#  'C1454671890': ['jon42@example.org', {'id': 887}],
#  'C1454826238': ['dfletcher@example.net', {'id': 888}],
#  'C1454930581': ['timothysmith@example.net', {'id': 889}],
#  'C1456029725': ['daustin@example.net', {'id': 890}],
#  'C1456179400': ['jamestanya@example.net', {'id': 891}],
#  'C1456851744': ['andrea92@example.net', {'id': 892}],
#  'C1457086535': ['ybarnes@example.net', {'id': 893}],
#  'C1457092141': ['christinarichardson@example.com', {'id': 894}],
#  'C1457264318': ['adurham@example.net', {'id': 895}],
#  'C1457388461': ['bjohnston@example.net', {'id': 896}],
#  'C145901862': ['millerrobert@example.org', {'id': 897}],
#  'C1459624061': ['williamsgeorge@example.net', {'id': 898}],
#  'C1459810780': ['loriwalter@example.com', {'id': 899}],
#  'C1460082550': ['joshuajensen@example.org', {'id': 900}],
#  'C1461183154': ['smithjeffrey@example.com', {'id': 901}],
#  'C1461183743': ['carol08@example.com', {'id': 902}],
#  'C1461258616': ['ryanhess@example.org', {'id': 903}],
#  'C1461774305': ['villegaspaige@example.net', {'id': 904}],
#  'C1463141739': ['mosleyangela@example.org', {'id': 905}],
#  'C1463356115': ['baileyscott@example.org', {'id': 906}],
#  'C1463833315': ['matthew15@example.com', {'id': 907}],
#  'C1464030920': ['thomasandrew@example.org', {'id': 908}],
#  'C1464489812': ['albert70@example.net', {'id': 909}],
#  'C146494822': ['smithrhonda@example.net', {'id': 910}],
#  'C146553626': ['pdaniels@example.com', {'id': 911}],
#  'C1465698425': ['iconway@example.org', {'id': 912}],
#  'C1465725042': ['david66@example.net', {'id': 913}],
#  'C1466730207': ['royschmidt@example.com', {'id': 914}],
#  'C1467497219': ['byrdchristopher@example.org', {'id': 915}],
#  'C1467832188': ['rebeccarichardson@example.net', {'id': 916}],
#  'C1468082478': ['jordandavid@example.org', {'id': 917}],
#  'C1468773146': ['ihart@example.com', {'id': 918}],
#  'C1469453217': ['travisvillegas@example.com', {'id': 919}],
#  'C1470676414': ['christophercervantes@example.org', {'id': 920}],
#  'C1471216995': ['alexander23@example.net', {'id': 921}],
#  'C1472480119': ['coleperry@example.org', {'id': 922}],
#  'C1472579779': ['tara69@example.org', {'id': 923}],
#  'C1474149613': ['kholt@example.com', {'id': 924}],
#  'C1474428806': ['susan80@example.net', {'id': 925}],
#  'C1474786056': ['brandon54@example.com', {'id': 926}],
#  'C1474976180': ['aaguilar@example.com', {'id': 927}],
#  'C1475317372': ['clarktodd@example.org', {'id': 928}],
#  'C1475486134': ['carterray@example.com', {'id': 929}],
#  'C1475799889': ['qthompson@example.net', {'id': 930}],
#  'C1476101537': ['ichase@example.com', {'id': 931}],
#  'C1476138873': ['lgutierrez@example.org', {'id': 932}],
#  'C1476491893': ['eddie88@example.net', {'id': 933}],
#  'C1476505660': ['pmccarthy@example.net', {'id': 934}],
#  'C1477378413': ['wendyobrien@example.org', {'id': 935}],
#  'C1477499235': ['nicholas07@example.net', {'id': 936}],
#  'C1480064437': ['owenskimberly@example.net', {'id': 937}],
#  'C1480193980': ['pachecomegan@example.com', {'id': 938}],
#  'C1480367576': ['ashleyspencer@example.org', {'id': 939}],
#  'C1480799932': ['brandon50@example.com', {'id': 940}],
#  'C1482560016': ['aaronjohnson@example.org', {'id': 941}],
#  'C1482659693': ['cantuapril@example.com', {'id': 942}],
#  'C1483007108': ['lindsay76@example.net', {'id': 943}],
#  'C1483054025': ['jaymoss@example.org', {'id': 944}],
#  'C1483927110': ['garciajoseph@example.org', {'id': 945}],
#  'C1484573422': ['ashley31@example.net', {'id': 946}],
#  'C1484585237': ['ericbutler@example.org', {'id': 947}],
#  'C1486017704': ['danielle70@example.net', {'id': 948}],
#  'C1486069778': ['walshchristopher@example.net', {'id': 949}],
#  'C1486961552': ['allenralph@example.com', {'id': 950}],
#  'C148765233': ['elindsey@example.net', {'id': 951}],
#  'C1487874353': ['jameswilson@example.org', {'id': 952}],
#  'C1487982242': ['taylorronnie@example.com', {'id': 953}],
#  'C1488142454': ['wongjennifer@example.org', {'id': 954}],
#  'C1489078579': ['robinchavez@example.net', {'id': 955}],
#  'C1489294793': ['sarah37@example.org', {'id': 956}],
#  'C1489632788': ['paulmartin@example.com', {'id': 957}],
#  'C1489836575': ['adamjohnson@example.org', {'id': 958}],
#  'C1490048317': ['jamesbrooks@example.net', {'id': 959}],
#  'C1490416909': ['nmcgee@example.org', {'id': 960}],
#  'C1490935984': ['brettochoa@example.net', {'id': 961}],
#  'C1491288577': ['mendozachelsea@example.org', {'id': 962}],
#  'C1491844959': ['xblake@example.com', {'id': 963}],
#  'C1492110515': ['kyle88@example.com', {'id': 964}],
#  'C1494778598': ['ojames@example.org', {'id': 965}],
#  'C1494829095': ['deanjennifer@example.org', {'id': 966}],
#  'C149511515': ['saraharias@example.net', {'id': 967}],
#  'C1495486273': ['moorejennifer@example.org', {'id': 968}],
#  'C1495681901': ['youngshawn@example.org', {'id': 969}],
#  'C1496334304': ['maldonadojennifer@example.com', {'id': 970}],
#  'C1496962993': ['simmonsbarry@example.com', {'id': 971}],
#  'C149698808': ['rstanton@example.com', {'id': 972}],
#  'C1497135910': ['tadams@example.net', {'id': 973}],
#  'C1497367004': ['angelagarner@example.org', {'id': 974}],
#  'C1497895052': ['patricia79@example.net', {'id': 975}],
#  'C1499019507': ['laurenking@example.net', {'id': 976}],
#  'C1499092508': ['brandyjackson@example.org', {'id': 977}],
#  'C1499241933': ['amyhowell@example.org', {'id': 978}],
#  'C1499363341': ['johnsonmelissa@example.net', {'id': 979}],
#  'C1499701993': ['mchandler@example.net', {'id': 980}],
#  'C1501124312': ['walkertina@example.org', {'id': 981}],
#  'C1501156188': ['davisalice@example.org', {'id': 982}],
#  'C1501782229': ['hernandezshannon@example.com', {'id': 983}],
#  'C1502465707': ['isabelkeller@example.com', {'id': 984}],
#  'C150273597': ['bsingh@example.net', {'id': 985}],
#  'C1502804084': ['carrie91@example.org', {'id': 986}],
#  'C1503009287': ['wmoran@example.com', {'id': 987}],
#  'C1503504810': ['fieldsmichael@example.com', {'id': 988}],
#  'C1504341710': ['racheloliver@example.net', {'id': 989}],
#  'C150523972': ['whitney97@example.com', {'id': 990}],
#  'C1505467955': ['hamptonpedro@example.com', {'id': 991}],
#  'C150587559': ['james66@example.net', {'id': 992}],
#  'C1506066038': ['elizabeth09@example.org', {'id': 993}],
#  'C1506293914': ['garcialuke@example.org', {'id': 994}],
#  'C1507237884': ['thompsonjohn@example.net', {'id': 995}],
#  'C1508025585': ['nicholasyoung@example.org', {'id': 996}],
#  'C150820973': ['michaelgordon@example.org', {'id': 997}],
#  'C1508373758': ['markandrews@example.com', {'id': 998}],
#  'C150891114': ['tommy19@example.com', {'id': 999}],
#  ...}

# %% [markdown]
# ### Step 3: create a mapping for dependent fields: merchant and category

# %%
merchant = dict(zip(df['merchant'], df['category']))

# %%
for i, m in enumerate(merchant.keys()):
    merchant[m] = [merchant[m]] + [{'id': i}]

# %%
merchant
# Out:
# {'M348934600': ['transportation', {'id': 0}],
#  'M151143676': ['barsandrestaurants', {'id': 1}],
#  'M1198415165': ['wellnessandbeauty', {'id': 2}],
#  'M480139044': ['health', {'id': 3}],
#  'M1823072687': ['transportation', {'id': 4}],
#  'M85975013': ['food', {'id': 5}],
#  'M209847108': ['wellnessandbeauty', {'id': 6}],
#  'M855959430': ['hyper', {'id': 7}],
#  'M1535107174': ['wellnessandbeauty', {'id': 8}],
#  'M1600850729': ['fashion', {'id': 9}],
#  'M349281107': ['fashion', {'id': 10}],
#  'M1946091778': ['wellnessandbeauty', {'id': 11}],
#  'M1872033263': ['home', {'id': 12}],
#  'M1888755466': ['otherservices', {'id': 13}],
#  'M348875670': ['hotelservices', {'id': 14}],
#  'M840466850': ['tech', {'id': 15}],
#  'M1053599405': ['health', {'id': 16}],
#  'M547558035': ['fashion', {'id': 17}],
#  'M2122776122': ['home', {'id': 18}],
#  'M923029380': ['home', {'id': 19}],
#  'M692898500': ['health', {'id': 20}],
#  'M1649169323': ['sportsandtoys', {'id': 21}],
#  'M980657600': ['sportsandtoys', {'id': 22}],
#  'M1313686961': ['contents', {'id': 23}],
#  'M1873032707': ['hotelservices', {'id': 24}],
#  'M50039827': ['health', {'id': 25}],
#  'M677738360': ['contents', {'id': 26}],
#  'M2011752106': ['hotelservices', {'id': 27}],
#  'M857378720': ['hotelservices', {'id': 28}],
#  'M1400236507': ['home', {'id': 29}],
#  'M1741626453': ['sportsandtoys', {'id': 30}],
#  'M3697346': ['leisure', {'id': 31}],
#  'M1352454843': ['hotelservices', {'id': 32}],
#  'M1842530320': ['tech', {'id': 33}],
#  'M1294758098': ['leisure', {'id': 34}],
#  'M1748431652': ['wellnessandbeauty', {'id': 35}],
#  'M1913465890': ['health', {'id': 36}],
#  'M732195782': ['travel', {'id': 37}],
#  'M78078399': ['wellnessandbeauty', {'id': 38}],
#  'M2080407379': ['travel', {'id': 39}],
#  'M45060432': ['hotelservices', {'id': 40}],
#  'M17379832': ['sportsandtoys', {'id': 41}],
#  'M495352832': ['travel', {'id': 42}],
#  'M1788569036': ['sportsandtoys', {'id': 43}],
#  'M97925176': ['wellnessandbeauty', {'id': 44}],
#  'M1353266412': ['hotelservices', {'id': 45}],
#  'M933210764': ['sportsandtoys', {'id': 46}],
#  'M117188757': ['home', {'id': 47}]}

# %% [markdown]
# ### Step 4: Analyse the min-max numerical ID for the customer, merchant, age, and amount

# %%
pd.Series(customer.keys()).apply(lambda x: len(x)).min()
# Out:
# 8

# %%
pd.Series(customer.keys()).apply(lambda x: len(x)).max()
# Out:
# 11

# %%
pd.Series(merchant.keys()).apply(lambda x: len(x)).min()
# Out:
# 8

# %%
pd.Series(merchant.keys()).apply(lambda x: len(x)).max()
# Out:
# 11

# %%
df.age.min(), df.age.max()
# Out:
# (0, 6)

# %%
df.amount.min(), df.amount.max()
# Out:
# (0.0, 6888.3)

# %%
df.timestamp.min(), df.timestamp.max()
# Out:
# ('2023-01-01 00:00:00', '2023-01-26 08:42:03.889555822')

# %%
customer_range = pd.Series(customer.keys()).apply(lambda x: len(x)).min(), pd.Series(customer.keys()).apply(lambda x: len(x)).max()
customer_range=[math.pow(10,x) for x in customer_range]

# %%
merchant_range = pd.Series(merchant.keys()).apply(lambda x: len(x)).min(), pd.Series(merchant.keys()).apply(lambda x: len(x)).max()
merchant_range = [math.pow(10,x) for x in merchant_range]

# %%
age_range = df.age.min(), df.age.max()

# %%
amount_range = df.amount.min(), df.amount.max()

# %%
timestamp_range = df.timestamp.min(), df.timestamp.max()

# %%
customer_range, merchant_range, age_range, amount_range, timestamp_range
# Out:
# ((8, 11),
#  (8, 11),
#  (0, 6),
#  (0.0, 6888.3),
#  ('2023-01-01 00:00:00', '2023-01-26 08:42:03.889555822'))

# %% [markdown]
# ### Step 5: Generate 50000 rows of syn data

# %%
syn_df = pd.DataFrame(columns=df.columns, index=range(50000))

# %%
syn_df
# Out:
#       customer email  age gender merchant category amount fraud timestamp
# 0          NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 1          NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 2          NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 3          NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 4          NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# ...        ...   ...  ...    ...      ...      ...    ...   ...       ...
# 49995      NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 49996      NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 49997      NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 49998      NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
# 49999      NaN   NaN  NaN    NaN      NaN      NaN    NaN   NaN       NaN
#
# [50000 rows x 9 columns]

# %% [markdown]
# ### Step 6: Generate random data for dependent fields using original mapping

# %%
total_customers = max([x[1]['id'] for x in customer.values()])+1

# %%
total_merchants = max([x[1]['id'] for x in merchant.values()]) +1

# %%
fake = Faker()

# %%
syn_customer = {
    'id': [f'C{round(random.uniform(*customer_range))}' for _ in range(50000)],
    'email': [fake.email() for _ in range(50000)]
}

# %%
syn_merchant = {
    'id': [f'M{round(random.uniform(*merchant_range))}' for _ in range(50000)],
    'category': [random.choice(tuple([x[0] for x in merchant.values()])) for _ in range(50000)]
}

# %% [markdown]
# ### Step 7: Generate random data for each field

# %%
age = [round(random.uniform(*age_range)) for _ in range(50000)]

# %%
gender = [random.choice(['M', 'F']) for _ in range(50000)]

# %%
amount = [random.uniform(*amount_range) for _ in range(50000)]

# %%
fraud = random.choices([0, 1], weights=[0.15, 0.85],k=50000)

# %%
timestamp = pd.date_range(*timestamp_range, 50000)

# %% [markdown]
# ### Step 8: Combine all the data

# %%
syn_df['customer'] = syn_customer['id']
syn_df['email'] = syn_customer['email']
syn_df['age'] = age
syn_df['gender'] = gender
syn_df['merchant'] = syn_merchant['id']
syn_df['category'] = syn_merchant['category']
syn_df['amount'] = amount
syn_df['fraud'] = fraud
syn_df['timestamp'] = timestamp

# %%
syn_df
# Out:
#            customer                        email  age gender      merchant  \
# 0      C77395562331     ingramjoseph@example.org    2      M  M94843641225
# 1      C67914289182         dcompton@example.org    1      F  M79408136014
# 2      C42794279423      penacharles@example.net    4      M   M4860306650
# 3      C44216027936        william89@example.net    1      F  M47437737467
# 4      C31997663343  barnettmichaela@example.org    1      F  M25372697670
# ...             ...                          ...  ...    ...           ...
# 49995  C99510420281        tarablack@example.org    1      F  M27691809714
# 49996  C45559484738     thomasashley@example.org    0      M  M34564484727
# 49997  C45331207584         edward63@example.org    6      M  M72097655547
# 49998  C17668889870       samantha92@example.org    5      F  M90065275742
# 49999  C97993426846        kingdonna@example.com    4      M  M71062297790
#
#                 category       amount  fraud                     timestamp
# 0      wellnessandbeauty  6407.074444      0 2023-01-01 00:00:00.000000000
# 1                leisure  1324.917208      1 2023-01-01 00:00:43.827354338
# 2      wellnessandbeauty  3094.339417      0 2023-01-01 00:01:27.654708676
# 3                   tech  1665.283673      1 2023-01-01 00:02:11.482063014
# 4               contents  3130.694459      1 2023-01-01 00:02:55.309417352
# ...                  ...          ...    ...                           ...
# 49995  wellnessandbeauty  2656.259104      1 2023-01-26 08:39:08.580138469
# 49996      hotelservices  1451.187341      1 2023-01-26 08:39:52.407492807
# 49997             travel  4966.442921      1 2023-01-26 08:40:36.234847145
# 49998               home  2279.201673      1 2023-01-26 08:41:20.062201483
# 49999           contents  1221.868655      1 2023-01-26 08:42:03.889555822
#
# [50000 rows x 9 columns]

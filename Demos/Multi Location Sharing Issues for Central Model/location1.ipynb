# %% [markdown]
# # Due to data policies, this data can't be shared to central location where the model is stored and refined.

# %%
import rockfish as rf
import rockfish.actions as ra

# %%
data = rf.Dataset.from_csv('loc1', './location1.csv')

# %%
data.to_pandas().head()
# Out:
#                 timestamp      amount  age gender     merchant category  \
# 0 2023-01-04 01:13:59.021  172.731084    3      F   M480139044   health
# 1 2023-01-09 11:44:38.836  132.292031    4      F  M1823072687   health
# 2 2023-01-10 09:37:59.665  312.221864    4      F   M480139044   health
# 3 2023-01-19 03:18:15.512  234.867520    3      M   M480139044   health
# 4 2023-01-12 06:58:34.742  218.621997    2      F   M480139044   health
#
#    fraud  customer
# 0      1     108.0
# 1      1     608.0
# 2      1     608.0
# 3      1     618.0
# 4      1     714.0

# %%
conn = rf.Connection.from_env()

# %%
join_customer = ra.JoinFields(fields=['customer', 'email'], append_field='customer')
join_merchant = ra.JoinFields(fields=['merchant', 'category'], append_field='merchant')
split_customer = ra.SplitField(field='customer', append_fields=['customer', 'email'])
split_merchant = ra.SplitField(field='merchant', append_fields=['merchant', 'category'])

# %%
encoder_config = ra.TrainTimeGAN.DatasetConfig(
    timestamp=ra.TrainTimeGAN.TimestampConfig(field="timestamp"),
    metadata=[
        ra.TrainTimeGAN.FieldConfig(field="customer", type="session"),
        ra.TrainTimeGAN.FieldConfig(field="age", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="gender", type="categorical"),
    ],
    measurements=[
        ra.TrainTimeGAN.FieldConfig(field="merchant", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="category", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="amount", type="continuous"),
        ra.TrainTimeGAN.FieldConfig(field="fraud", type="categorical"),
    ],
)

model_config = ra.TrainTimeGAN.DGConfig(
    sample_len=4,
    epoch=250,
    epoch_checkpoint_freq=100,
    sessions=4000,
    batch_size=512,
    activate_normalization_per_sample=False,
    g_lr=0.001,
    d_lr=0.001,
    attr_d_lr=0.001,
    generator_attribute_num_units=100,
    generator_attribute_num_layers=3,
    generator_feature_num_units=100,
    generator_feature_num_layers=5,
    discriminator_num_layers=5,
    discriminator_num_units=200,
    attr_discriminator_num_layers=5,
    attr_discriminator_num_units=200
)

config = ra.TrainTimeGAN.Config(
    encoder=encoder_config,
    doppelganger=model_config,
)
train = ra.TrainTimeGAN(config)

# %%
train.config()
# Out:
# Config(
#     doppelganger=DGConfig(
#         sample_len=4,
#         activate_normalization_per_sample=False,
#         generator_attribute_num_layers=3,
#         generator_feature_num_layers=5,
#         epoch=250,
#         epoch_checkpoint_freq=100,
#         batch_size=512,
#         g_lr=0.001,
#         d_lr=0.001,
#         attr_d_beta1=0.5,
#         sessions=4000,
#         extras={
#             'attr_d_lr': 0.001,
#             'generator_attribute_num_units': 100,
#             'generator_feature_num_units': 100,
#             'discriminator_num_layers': 5,
#             'discriminator_num_units': 200,
#             'attr_discriminator_num_layers': 5,
#             'attr_discriminator_num_units': 200
#         }
#     ),
#     encoder=DatasetConfig(
#         name='default',
#         metadata=[
#             FieldConfig(field='customer', type='session', semantic_type=None),
#             FieldConfig(field='age', type='categorical', semantic_type=None),
#             FieldConfig(
#                 field='gender',
#                 type='categorical',
#                 semantic_type=None
#             )
#         ],
#         measurements=[
#             FieldConfig(
#                 field='merchant',
#                 type='categorical',
#                 semantic_type=None
#             ),
#             FieldConfig(
#                 field='category',
#                 type='categorical',
#                 semantic_type=None
#             ),
#             FieldConfig(field='amount', type='continuous', semantic_type=None),
#             FieldConfig(field='fraud', type='categorical', semantic_type=None)
#         ],
#         timestamp=TimestampConfig(field='timestamp', unit='ms', strptime=None),
#         privacy=None,
#         embedding=None,
#         group_by=None,
#         timeseries=None
#     ),
#     model_ids=None
# )

# %%
builder = rf.WorkflowBuilder()
builder.add_path(data, train)
workflow = await builder.start(conn)
workflow.id()
# Out:
# '5CZTvI0AdaS2OsdKGvq30C'

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-09-20T21:07:54Z dataset-load: INFO Loading dataset '4nEHxcETz97dTm43RwuNPO' with 7386 rows
# 2024-09-20T21:07:55Z train-time-gan: INFO Starting DG training job
# 2024-09-20T21:07:57Z train-time-gan: INFO Epoch 1 completed.
# 2024-09-20T21:07:58Z train-time-gan: INFO Epoch 2 completed.
# 2024-09-20T21:07:59Z train-time-gan: INFO Epoch 3 completed.
# 2024-09-20T21:08:00Z train-time-gan: INFO Epoch 4 completed.
# 2024-09-20T21:08:01Z train-time-gan: INFO Epoch 5 completed.
# 2024-09-20T21:08:02Z train-time-gan: INFO Epoch 6 completed.
# 2024-09-20T21:08:03Z train-time-gan: INFO Epoch 7 completed.
# 2024-09-20T21:08:04Z train-time-gan: INFO Epoch 8 completed.
# 2024-09-20T21:08:05Z train-time-gan: INFO Epoch 9 completed.
# 2024-09-20T21:08:06Z train-time-gan: INFO Epoch 10 completed.
# 2024-09-20T21:08:07Z train-time-gan: INFO Epoch 11 completed.
# 2024-09-20T21:08:09Z train-time-gan: INFO Epoch 12 completed.
# 2024-09-20T21:08:10Z train-time-gan: INFO Epoch 13 completed.
# 2024-09-20T21:08:11Z train-time-gan: INFO Epoch 14 completed.
# 2024-09-20T21:08:12Z train-time-gan: INFO Epoch 15 completed.
# 2024-09-20T21:08:13Z train-time-gan: INFO Epoch 16 completed.
# 2024-09-20T21:08:14Z train-time-gan: INFO Epoch 17 completed.
# 2024-09-20T21:08:15Z train-time-gan: INFO Epoch 18 completed.
# 2024-09-20T21:08:16Z train-time-gan: INFO Epoch 19 completed.
# 2024-09-20T21:08:17Z train-time-gan: INFO Epoch 20 completed.
# 2024-09-20T21:08:18Z train-time-gan: INFO Epoch 21 completed.
# 2024-09-20T21:08:19Z train-time-gan: INFO Epoch 22 completed.
# 2024-09-20T21:08:20Z train-time-gan: INFO Epoch 23 completed.
# 2024-09-20T21:08:21Z train-time-gan: INFO Epoch 24 completed.
# 2024-09-20T21:08:22Z train-time-gan: INFO Epoch 25 completed.
# 2024-09-20T21:08:23Z train-time-gan: INFO Epoch 26 completed.
# 2024-09-20T21:08:24Z train-time-gan: INFO Epoch 27 completed.
# 2024-09-20T21:08:25Z train-time-gan: INFO Epoch 28 completed.
# 2024-09-20T21:08:26Z train-time-gan: INFO Epoch 29 completed.
# 2024-09-20T21:08:27Z train-time-gan: INFO Epoch 30 completed.
# 2024-09-20T21:08:28Z train-time-gan: INFO Epoch 31 completed.
# 2024-09-20T21:08:29Z train-time-gan: INFO Epoch 32 completed.
# 2024-09-20T21:08:30Z train-time-gan: INFO Epoch 33 completed.
# 2024-09-20T21:08:30Z train-time-gan: INFO Epoch 34 completed.
# 2024-09-20T21:08:31Z train-time-gan: INFO Epoch 35 completed.
# 2024-09-20T21:08:32Z train-time-gan: INFO Epoch 36 completed.
# 2024-09-20T21:08:33Z train-time-gan: INFO Epoch 37 completed.
# 2024-09-20T21:08:34Z train-time-gan: INFO Epoch 38 completed.
# 2024-09-20T21:08:35Z train-time-gan: INFO Epoch 39 completed.
# 2024-09-20T21:08:36Z train-time-gan: INFO Epoch 40 completed.
# 2024-09-20T21:08:37Z train-time-gan: INFO Epoch 41 completed.
# 2024-09-20T21:08:38Z train-time-gan: INFO Epoch 42 completed.
# 2024-09-20T21:08:39Z train-time-gan: INFO Epoch 43 completed.
# 2024-09-20T21:08:40Z train-time-gan: INFO Epoch 44 completed.
# 2024-09-20T21:08:41Z train-time-gan: INFO Epoch 45 completed.
# 2024-09-20T21:08:42Z train-time-gan: INFO Epoch 46 completed.
# 2024-09-20T21:08:43Z train-time-gan: INFO Epoch 47 completed.
# 2024-09-20T21:08:44Z train-time-gan: INFO Epoch 48 completed.
# 2024-09-20T21:08:45Z train-time-gan: INFO Epoch 49 completed.
# 2024-09-20T21:08:46Z train-time-gan: INFO Epoch 50 completed.
# 2024-09-20T21:08:47Z train-time-gan: INFO Epoch 51 completed.
# 2024-09-20T21:08:48Z train-time-gan: INFO Epoch 52 completed.
# 2024-09-20T21:08:49Z train-time-gan: INFO Epoch 53 completed.
# 2024-09-20T21:08:50Z train-time-gan: INFO Epoch 54 completed.
# 2024-09-20T21:08:51Z train-time-gan: INFO Epoch 55 completed.
# 2024-09-20T21:08:52Z train-time-gan: INFO Epoch 56 completed.
# 2024-09-20T21:08:53Z train-time-gan: INFO Epoch 57 completed.
# 2024-09-20T21:08:53Z train-time-gan: INFO Epoch 58 completed.
# 2024-09-20T21:08:54Z train-time-gan: INFO Epoch 59 completed.
# 2024-09-20T21:08:55Z train-time-gan: INFO Epoch 60 completed.
# 2024-09-20T21:08:56Z train-time-gan: INFO Epoch 61 completed.
# 2024-09-20T21:08:57Z train-time-gan: INFO Epoch 62 completed.
# 2024-09-20T21:08:58Z train-time-gan: INFO Epoch 63 completed.
# 2024-09-20T21:08:59Z train-time-gan: INFO Epoch 64 completed.
# 2024-09-20T21:09:00Z train-time-gan: INFO Epoch 65 completed.
# 2024-09-20T21:09:01Z train-time-gan: INFO Epoch 66 completed.
# 2024-09-20T21:09:02Z train-time-gan: INFO Epoch 67 completed.
# 2024-09-20T21:09:03Z train-time-gan: INFO Epoch 68 completed.
# 2024-09-20T21:09:04Z train-time-gan: INFO Epoch 69 completed.
# 2024-09-20T21:09:05Z train-time-gan: INFO Epoch 70 completed.
# 2024-09-20T21:09:06Z train-time-gan: INFO Epoch 71 completed.
# 2024-09-20T21:09:07Z train-time-gan: INFO Epoch 72 completed.
# 2024-09-20T21:09:08Z train-time-gan: INFO Epoch 73 completed.
# 2024-09-20T21:09:09Z train-time-gan: INFO Epoch 74 completed.
# 2024-09-20T21:09:10Z train-time-gan: INFO Epoch 75 completed.
# 2024-09-20T21:09:11Z train-time-gan: INFO Epoch 76 completed.
# 2024-09-20T21:09:12Z train-time-gan: INFO Epoch 77 completed.
# 2024-09-20T21:09:13Z train-time-gan: INFO Epoch 78 completed.
# 2024-09-20T21:09:14Z train-time-gan: INFO Epoch 79 completed.
# 2024-09-20T21:09:15Z train-time-gan: INFO Epoch 80 completed.
# 2024-09-20T21:09:15Z train-time-gan: INFO Epoch 81 completed.
# 2024-09-20T21:09:16Z train-time-gan: INFO Epoch 82 completed.
# 2024-09-20T21:09:17Z train-time-gan: INFO Epoch 83 completed.
# 2024-09-20T21:09:18Z train-time-gan: INFO Epoch 84 completed.
# 2024-09-20T21:09:19Z train-time-gan: INFO Epoch 85 completed.
# 2024-09-20T21:09:20Z train-time-gan: INFO Epoch 86 completed.
# 2024-09-20T21:09:21Z train-time-gan: INFO Epoch 87 completed.
# 2024-09-20T21:09:22Z train-time-gan: INFO Epoch 88 completed.
# 2024-09-20T21:09:23Z train-time-gan: INFO Epoch 89 completed.
# 2024-09-20T21:09:24Z train-time-gan: INFO Epoch 90 completed.
# 2024-09-20T21:09:25Z train-time-gan: INFO Epoch 91 completed.
# 2024-09-20T21:09:26Z train-time-gan: INFO Epoch 92 completed.
# 2024-09-20T21:09:27Z train-time-gan: INFO Epoch 93 completed.
# 2024-09-20T21:09:28Z train-time-gan: INFO Epoch 94 completed.
# 2024-09-20T21:09:29Z train-time-gan: INFO Epoch 95 completed.
# 2024-09-20T21:09:30Z train-time-gan: INFO Epoch 96 completed.
# 2024-09-20T21:09:31Z train-time-gan: INFO Epoch 97 completed.
# 2024-09-20T21:09:32Z train-time-gan: INFO Epoch 98 completed.
# 2024-09-20T21:09:33Z train-time-gan: INFO Epoch 99 completed.
# 2024-09-20T21:09:34Z train-time-gan: INFO Epoch 100 completed.
# 2024-09-20T21:09:35Z train-time-gan: INFO Epoch 101 completed.
# 2024-09-20T21:09:36Z train-time-gan: INFO Epoch 102 completed.
# 2024-09-20T21:09:37Z train-time-gan: INFO Epoch 103 completed.
# 2024-09-20T21:09:38Z train-time-gan: INFO Epoch 104 completed.
# 2024-09-20T21:09:39Z train-time-gan: INFO Epoch 105 completed.
# 2024-09-20T21:09:40Z train-time-gan: INFO Epoch 106 completed.
# 2024-09-20T21:09:41Z train-time-gan: INFO Epoch 107 completed.
# 2024-09-20T21:09:42Z train-time-gan: INFO Epoch 108 completed.
# 2024-09-20T21:09:43Z train-time-gan: INFO Epoch 109 completed.
# 2024-09-20T21:09:43Z train-time-gan: INFO Epoch 110 completed.
# 2024-09-20T21:09:44Z train-time-gan: INFO Epoch 111 completed.
# 2024-09-20T21:09:45Z train-time-gan: INFO Epoch 112 completed.
# 2024-09-20T21:09:46Z train-time-gan: INFO Epoch 113 completed.
# 2024-09-20T21:09:47Z train-time-gan: INFO Epoch 114 completed.
# 2024-09-20T21:09:48Z train-time-gan: INFO Epoch 115 completed.
# 2024-09-20T21:09:49Z train-time-gan: INFO Epoch 116 completed.
# 2024-09-20T21:09:50Z train-time-gan: INFO Epoch 117 completed.
# 2024-09-20T21:09:51Z train-time-gan: INFO Epoch 118 completed.
# 2024-09-20T21:09:52Z train-time-gan: INFO Epoch 119 completed.
# 2024-09-20T21:09:53Z train-time-gan: INFO Epoch 120 completed.
# 2024-09-20T21:09:54Z train-time-gan: INFO Epoch 121 completed.
# 2024-09-20T21:09:55Z train-time-gan: INFO Epoch 122 completed.
# 2024-09-20T21:09:56Z train-time-gan: INFO Epoch 123 completed.
# 2024-09-20T21:09:57Z train-time-gan: INFO Epoch 124 completed.
# 2024-09-20T21:09:58Z train-time-gan: INFO Epoch 125 completed.
# 2024-09-20T21:09:59Z train-time-gan: INFO Epoch 126 completed.
# 2024-09-20T21:10:00Z train-time-gan: INFO Epoch 127 completed.
# 2024-09-20T21:10:01Z train-time-gan: INFO Epoch 128 completed.
# 2024-09-20T21:10:02Z train-time-gan: INFO Epoch 129 completed.
# 2024-09-20T21:10:03Z train-time-gan: INFO Epoch 130 completed.
# 2024-09-20T21:10:04Z train-time-gan: INFO Epoch 131 completed.
# 2024-09-20T21:10:05Z train-time-gan: INFO Epoch 132 completed.
# 2024-09-20T21:10:06Z train-time-gan: INFO Epoch 133 completed.
# 2024-09-20T21:10:07Z train-time-gan: INFO Epoch 134 completed.
# 2024-09-20T21:10:08Z train-time-gan: INFO Epoch 135 completed.
# 2024-09-20T21:10:09Z train-time-gan: INFO Epoch 136 completed.
# 2024-09-20T21:10:10Z train-time-gan: INFO Epoch 137 completed.
# 2024-09-20T21:10:11Z train-time-gan: INFO Epoch 138 completed.
# 2024-09-20T21:10:12Z train-time-gan: INFO Epoch 139 completed.
# 2024-09-20T21:10:12Z train-time-gan: INFO Epoch 140 completed.
# 2024-09-20T21:10:13Z train-time-gan: INFO Epoch 141 completed.
# 2024-09-20T21:10:14Z train-time-gan: INFO Epoch 142 completed.
# 2024-09-20T21:10:15Z train-time-gan: INFO Epoch 143 completed.
# 2024-09-20T21:10:16Z train-time-gan: INFO Epoch 144 completed.
# 2024-09-20T21:10:17Z train-time-gan: INFO Epoch 145 completed.
# 2024-09-20T21:10:18Z train-time-gan: INFO Epoch 146 completed.
# 2024-09-20T21:10:19Z train-time-gan: INFO Epoch 147 completed.
# 2024-09-20T21:10:20Z train-time-gan: INFO Epoch 148 completed.
# 2024-09-20T21:10:21Z train-time-gan: INFO Epoch 149 completed.
# 2024-09-20T21:10:22Z train-time-gan: INFO Epoch 150 completed.
# 2024-09-20T21:10:23Z train-time-gan: INFO Epoch 151 completed.
# 2024-09-20T21:10:24Z train-time-gan: INFO Epoch 152 completed.
# 2024-09-20T21:10:25Z train-time-gan: INFO Epoch 153 completed.
# 2024-09-20T21:10:26Z train-time-gan: INFO Epoch 154 completed.
# 2024-09-20T21:10:27Z train-time-gan: INFO Epoch 155 completed.
# 2024-09-20T21:10:28Z train-time-gan: INFO Epoch 156 completed.
# 2024-09-20T21:10:29Z train-time-gan: INFO Epoch 157 completed.
# 2024-09-20T21:10:30Z train-time-gan: INFO Epoch 158 completed.
# 2024-09-20T21:10:31Z train-time-gan: INFO Epoch 159 completed.
# 2024-09-20T21:10:32Z train-time-gan: INFO Epoch 160 completed.
# 2024-09-20T21:10:33Z train-time-gan: INFO Epoch 161 completed.
# 2024-09-20T21:10:34Z train-time-gan: INFO Epoch 162 completed.
# 2024-09-20T21:10:35Z train-time-gan: INFO Epoch 163 completed.
# 2024-09-20T21:10:36Z train-time-gan: INFO Epoch 164 completed.
# 2024-09-20T21:10:37Z train-time-gan: INFO Epoch 165 completed.
# 2024-09-20T21:10:38Z train-time-gan: INFO Epoch 166 completed.
# 2024-09-20T21:10:39Z train-time-gan: INFO Epoch 167 completed.
# 2024-09-20T21:10:40Z train-time-gan: INFO Epoch 168 completed.
# 2024-09-20T21:10:41Z train-time-gan: INFO Epoch 169 completed.
# 2024-09-20T21:10:42Z train-time-gan: INFO Epoch 170 completed.
# 2024-09-20T21:10:42Z train-time-gan: INFO Epoch 171 completed.
# 2024-09-20T21:10:43Z train-time-gan: INFO Epoch 172 completed.
# 2024-09-20T21:10:44Z train-time-gan: INFO Epoch 173 completed.
# 2024-09-20T21:10:45Z train-time-gan: INFO Epoch 174 completed.
# 2024-09-20T21:10:46Z train-time-gan: INFO Epoch 175 completed.
# 2024-09-20T21:10:47Z train-time-gan: INFO Epoch 176 completed.
# 2024-09-20T21:10:48Z train-time-gan: INFO Epoch 177 completed.
# 2024-09-20T21:10:49Z train-time-gan: INFO Epoch 178 completed.
# 2024-09-20T21:10:50Z train-time-gan: INFO Epoch 179 completed.
# 2024-09-20T21:10:51Z train-time-gan: INFO Epoch 180 completed.
# 2024-09-20T21:10:52Z train-time-gan: INFO Epoch 181 completed.
# 2024-09-20T21:10:53Z train-time-gan: INFO Epoch 182 completed.
# 2024-09-20T21:10:54Z train-time-gan: INFO Epoch 183 completed.
# 2024-09-20T21:10:55Z train-time-gan: INFO Epoch 184 completed.
# 2024-09-20T21:10:56Z train-time-gan: INFO Epoch 185 completed.
# 2024-09-20T21:10:57Z train-time-gan: INFO Epoch 186 completed.
# 2024-09-20T21:10:58Z train-time-gan: INFO Epoch 187 completed.
# 2024-09-20T21:10:59Z train-time-gan: INFO Epoch 188 completed.
# 2024-09-20T21:11:00Z train-time-gan: INFO Epoch 189 completed.
# 2024-09-20T21:11:01Z train-time-gan: INFO Epoch 190 completed.
# 2024-09-20T21:11:02Z train-time-gan: INFO Epoch 191 completed.
# 2024-09-20T21:11:03Z train-time-gan: INFO Epoch 192 completed.
# 2024-09-20T21:11:04Z train-time-gan: INFO Epoch 193 completed.
# 2024-09-20T21:11:05Z train-time-gan: INFO Epoch 194 completed.
# 2024-09-20T21:11:06Z train-time-gan: INFO Epoch 195 completed.
# 2024-09-20T21:11:07Z train-time-gan: INFO Epoch 196 completed.
# 2024-09-20T21:11:08Z train-time-gan: INFO Epoch 197 completed.
# 2024-09-20T21:11:09Z train-time-gan: INFO Epoch 198 completed.
# 2024-09-20T21:11:10Z train-time-gan: INFO Epoch 199 completed.
# 2024-09-20T21:11:10Z train-time-gan: INFO Epoch 200 completed.
# 2024-09-20T21:11:11Z train-time-gan: INFO Epoch 201 completed.
# 2024-09-20T21:11:12Z train-time-gan: INFO Epoch 202 completed.
# 2024-09-20T21:11:13Z train-time-gan: INFO Epoch 203 completed.
# 2024-09-20T21:11:14Z train-time-gan: INFO Epoch 204 completed.
# 2024-09-20T21:11:15Z train-time-gan: INFO Epoch 205 completed.
# 2024-09-20T21:11:16Z train-time-gan: INFO Epoch 206 completed.
# 2024-09-20T21:11:17Z train-time-gan: INFO Epoch 207 completed.
# 2024-09-20T21:11:18Z train-time-gan: INFO Epoch 208 completed.
# 2024-09-20T21:11:19Z train-time-gan: INFO Epoch 209 completed.
# 2024-09-20T21:11:20Z train-time-gan: INFO Epoch 210 completed.
# 2024-09-20T21:11:21Z train-time-gan: INFO Epoch 211 completed.
# 2024-09-20T21:11:22Z train-time-gan: INFO Epoch 212 completed.
# 2024-09-20T21:11:23Z train-time-gan: INFO Epoch 213 completed.
# 2024-09-20T21:11:24Z train-time-gan: INFO Epoch 214 completed.
# 2024-09-20T21:11:25Z train-time-gan: INFO Epoch 215 completed.
# 2024-09-20T21:11:26Z train-time-gan: INFO Epoch 216 completed.
# 2024-09-20T21:11:27Z train-time-gan: INFO Epoch 217 completed.
# 2024-09-20T21:11:28Z train-time-gan: INFO Epoch 218 completed.
# 2024-09-20T21:11:29Z train-time-gan: INFO Epoch 219 completed.
# 2024-09-20T21:11:30Z train-time-gan: INFO Epoch 220 completed.
# 2024-09-20T21:11:31Z train-time-gan: INFO Epoch 221 completed.
# 2024-09-20T21:11:32Z train-time-gan: INFO Epoch 222 completed.
# 2024-09-20T21:11:33Z train-time-gan: INFO Epoch 223 completed.
# 2024-09-20T21:11:34Z train-time-gan: INFO Epoch 224 completed.
# 2024-09-20T21:11:35Z train-time-gan: INFO Epoch 225 completed.
# 2024-09-20T21:11:36Z train-time-gan: INFO Epoch 226 completed.
# 2024-09-20T21:11:37Z train-time-gan: INFO Epoch 227 completed.
# 2024-09-20T21:11:38Z train-time-gan: INFO Epoch 228 completed.
# 2024-09-20T21:11:39Z train-time-gan: INFO Epoch 229 completed.
# 2024-09-20T21:11:40Z train-time-gan: INFO Epoch 230 completed.
# 2024-09-20T21:11:40Z train-time-gan: INFO Epoch 231 completed.
# 2024-09-20T21:11:41Z train-time-gan: INFO Epoch 232 completed.
# 2024-09-20T21:11:42Z train-time-gan: INFO Epoch 233 completed.
# 2024-09-20T21:11:43Z train-time-gan: INFO Epoch 234 completed.
# 2024-09-20T21:11:44Z train-time-gan: INFO Epoch 235 completed.
# 2024-09-20T21:11:45Z train-time-gan: INFO Epoch 236 completed.
# 2024-09-20T21:11:46Z train-time-gan: INFO Epoch 237 completed.
# 2024-09-20T21:11:47Z train-time-gan: INFO Epoch 238 completed.
# 2024-09-20T21:11:48Z train-time-gan: INFO Epoch 239 completed.
# 2024-09-20T21:11:49Z train-time-gan: INFO Epoch 240 completed.
# 2024-09-20T21:11:50Z train-time-gan: INFO Epoch 241 completed.
# 2024-09-20T21:11:51Z train-time-gan: INFO Epoch 242 completed.
# 2024-09-20T21:11:52Z train-time-gan: INFO Epoch 243 completed.
# 2024-09-20T21:11:53Z train-time-gan: INFO Epoch 244 completed.
# 2024-09-20T21:11:54Z train-time-gan: INFO Epoch 245 completed.
# 2024-09-20T21:11:55Z train-time-gan: INFO Epoch 246 completed.
# 2024-09-20T21:11:56Z train-time-gan: INFO Epoch 247 completed.
# 2024-09-20T21:11:57Z train-time-gan: INFO Epoch 248 completed.
# 2024-09-20T21:11:58Z train-time-gan: INFO Epoch 249 completed.
# 2024-09-20T21:11:59Z train-time-gan: INFO Epoch 250 completed.
# 2024-09-20T21:12:01Z train-time-gan: INFO Training completed. Uploaded model fa1d624f-7794-11ef-bcc2-26425b76ab20

# %%
(await (await workflow.models().last()).add_labels(conn,location='location1_x')).labels
# Out:
# {'location': 'location1_x', 'workflow_id': '5CZTvI0AdaS2OsdKGvq30C'}

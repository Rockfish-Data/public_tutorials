# %% [markdown]
# # Due to data policies, this data can't be shared to central location where the model is stored and refined.

# %%
import rockfish as rf
import rockfish.actions as ra

# %%
data = rf.Dataset.from_csv('loc1', './location1.csv')

# %%
data.to_pandas().head()
# Out:
#      customer                    email age gender    merchant  \
# 0  C100045114  nmontgomery@example.net   4      M  M348934600
# 1  C100045114  nmontgomery@example.net   4      M  M348934600
# 2  C100045114  nmontgomery@example.net   4      M  M348934600
# 3  C100045114  nmontgomery@example.net   4      M  M348934600
# 4  C100045114  nmontgomery@example.net   4      M  M151143676
#
#              category  amount  fraud           timestamp
# 0      transportation   35.13      0 2023-01-01 00:00:00
# 1      transportation   27.63      0 2023-01-01 08:00:00
# 2      transportation   13.46      0 2023-01-01 16:00:00
# 3      transportation   28.86      0 2023-01-02 00:00:00
# 4  barsandrestaurants   64.99      0 2023-01-02 08:00:00

# %%
conn = rf.Connection.from_env()

# %%
join_customer = ra.JoinFields(fields=['customer', 'email'], append_field='customer')
join_merchant = ra.JoinFields(fields=['merchant', 'category'], append_field='merchant')
split_customer = ra.SplitField(field='customer', append_fields=['customer', 'email'])
split_merchant = ra.SplitField(field='merchant', append_fields=['merchant', 'category'])

# %%
encoder_config = ra.TrainTimeGAN.DatasetConfig(
    timestamp=ra.TrainTimeGAN.TimestampConfig(field="timestamp"),
    metadata=[
        ra.TrainTimeGAN.FieldConfig(field="customer", type="session"),
        ra.TrainTimeGAN.FieldConfig(field="age", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="gender", type="categorical"),
    ],
    measurements=[
        ra.TrainTimeGAN.FieldConfig(field="merchant", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="category", type="categorical"),
        ra.TrainTimeGAN.FieldConfig(field="amount", type="continuous"),
        ra.TrainTimeGAN.FieldConfig(field="fraud", type="categorical"),
    ],
)

model_config = ra.TrainTimeGAN.DGConfig(
    sample_len=4,
    epoch=250,
    epoch_checkpoint_freq=100,
    sessions=4000,
    batch_size=512,
    activate_normalization_per_sample=False,
    g_lr=0.001,
    d_lr=0.001,
    attr_d_lr=0.001,
    generator_attribute_num_units=100,
    generator_attribute_num_layers=3,
    generator_feature_num_units=100,
    generator_feature_num_layers=5,
    discriminator_num_layers=5,
    discriminator_num_units=200,
    attr_discriminator_num_layers=5,
    attr_discriminator_num_units=200
)

config = ra.TrainTimeGAN.Config(
    encoder=encoder_config,
    doppelganger=model_config,
)
train = ra.TrainTimeGAN(config)

# %%
train.config()
# Out:
# Config(
#     doppelganger=DGConfig(
#         sample_len=4,
#         activate_normalization_per_sample=False,
#         generator_attribute_num_layers=3,
#         generator_feature_num_layers=5,
#         epoch=250,
#         epoch_checkpoint_freq=100,
#         batch_size=512,
#         g_lr=0.001,
#         d_lr=0.001,
#         attr_d_beta1=0.5,
#         sessions=4000,
#         extras={
#             'attr_d_lr': 0.001,
#             'generator_attribute_num_units': 100,
#             'generator_feature_num_units': 100,
#             'discriminator_num_layers': 5,
#             'discriminator_num_units': 200,
#             'attr_discriminator_num_layers': 5,
#             'attr_discriminator_num_units': 200
#         }
#     ),
#     encoder=DatasetConfig(
#         name='default',
#         metadata=[
#             FieldConfig(field='customer', type='session', semantic_type=None),
#             FieldConfig(field='age', type='categorical', semantic_type=None),
#             FieldConfig(
#                 field='gender',
#                 type='categorical',
#                 semantic_type=None
#             )
#         ],
#         measurements=[
#             FieldConfig(
#                 field='merchant',
#                 type='categorical',
#                 semantic_type=None
#             ),
#             FieldConfig(
#                 field='category',
#                 type='categorical',
#                 semantic_type=None
#             ),
#             FieldConfig(field='amount', type='continuous', semantic_type=None),
#             FieldConfig(field='fraud', type='categorical', semantic_type=None)
#         ],
#         timestamp=TimestampConfig(field='timestamp', unit='ms', strptime=None),
#         privacy=None,
#         embedding=None,
#         group_by=None,
#         timeseries=None
#     ),
#     model_ids=None
# )

# %%
builder = rf.WorkflowBuilder()
builder.add_path(data, train)
workflow = await builder.start(conn)
workflow.id()
# Out:
# '6UfjK0pqV7S2RN3syFcVH2'

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-09-12T23:34:49Z dataset-load: INFO Loading dataset '2mimoHkX8GWxCnL7ssF7ku' with 8779 rows
# 2024-09-12T23:34:49Z train-time-gan: WARN Unsafe time cast on timestamp
# 2024-09-12T23:34:49Z train-time-gan: INFO Starting DG training job
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 1 completed.
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 2 completed.
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 3 completed.
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 4 completed.
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 5 completed.
# 2024-09-12T23:34:50Z train-time-gan: INFO Epoch 6 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 7 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 8 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 9 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 10 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 11 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 12 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 13 completed.
# 2024-09-12T23:34:51Z train-time-gan: INFO Epoch 14 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 15 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 16 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 17 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 18 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 19 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 20 completed.
# 2024-09-12T23:34:52Z train-time-gan: INFO Epoch 21 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 22 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 23 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 24 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 25 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 26 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 27 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 28 completed.
# 2024-09-12T23:34:53Z train-time-gan: INFO Epoch 29 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 30 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 31 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 32 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 33 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 34 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 35 completed.
# 2024-09-12T23:34:54Z train-time-gan: INFO Epoch 36 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 37 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 38 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 39 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 40 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 41 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 42 completed.
# 2024-09-12T23:34:55Z train-time-gan: INFO Epoch 43 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 44 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 45 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 46 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 47 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 48 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 49 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 50 completed.
# 2024-09-12T23:34:56Z train-time-gan: INFO Epoch 51 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 52 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 53 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 54 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 55 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 56 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 57 completed.
# 2024-09-12T23:34:57Z train-time-gan: INFO Epoch 58 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 59 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 60 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 61 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 62 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 63 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 64 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 65 completed.
# 2024-09-12T23:34:58Z train-time-gan: INFO Epoch 66 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 67 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 68 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 69 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 70 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 71 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 72 completed.
# 2024-09-12T23:34:59Z train-time-gan: INFO Epoch 73 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 74 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 75 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 76 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 77 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 78 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 79 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 80 completed.
# 2024-09-12T23:35:00Z train-time-gan: INFO Epoch 81 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 82 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 83 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 84 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 85 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 86 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 87 completed.
# 2024-09-12T23:35:01Z train-time-gan: INFO Epoch 88 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 89 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 90 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 91 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 92 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 93 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 94 completed.
# 2024-09-12T23:35:02Z train-time-gan: INFO Epoch 95 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 96 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 97 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 98 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 99 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 100 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 101 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 102 completed.
# 2024-09-12T23:35:03Z train-time-gan: INFO Epoch 103 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 104 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 105 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 106 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 107 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 108 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 109 completed.
# 2024-09-12T23:35:04Z train-time-gan: INFO Epoch 110 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 111 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 112 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 113 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 114 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 115 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 116 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 117 completed.
# 2024-09-12T23:35:05Z train-time-gan: INFO Epoch 118 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 119 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 120 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 121 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 122 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 123 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 124 completed.
# 2024-09-12T23:35:06Z train-time-gan: INFO Epoch 125 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 126 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 127 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 128 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 129 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 130 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 131 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 132 completed.
# 2024-09-12T23:35:07Z train-time-gan: INFO Epoch 133 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 134 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 135 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 136 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 137 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 138 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 139 completed.
# 2024-09-12T23:35:08Z train-time-gan: INFO Epoch 140 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 141 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 142 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 143 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 144 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 145 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 146 completed.
# 2024-09-12T23:35:09Z train-time-gan: INFO Epoch 147 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 148 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 149 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 150 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 151 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 152 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 153 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 154 completed.
# 2024-09-12T23:35:10Z train-time-gan: INFO Epoch 155 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 156 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 157 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 158 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 159 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 160 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 161 completed.
# 2024-09-12T23:35:11Z train-time-gan: INFO Epoch 162 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 163 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 164 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 165 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 166 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 167 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 168 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 169 completed.
# 2024-09-12T23:35:12Z train-time-gan: INFO Epoch 170 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 171 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 172 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 173 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 174 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 175 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 176 completed.
# 2024-09-12T23:35:13Z train-time-gan: INFO Epoch 177 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 178 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 179 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 180 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 181 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 182 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 183 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 184 completed.
# 2024-09-12T23:35:14Z train-time-gan: INFO Epoch 185 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 186 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 187 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 188 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 189 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 190 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 191 completed.
# 2024-09-12T23:35:15Z train-time-gan: INFO Epoch 192 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 193 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 194 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 195 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 196 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 197 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 198 completed.
# 2024-09-12T23:35:16Z train-time-gan: INFO Epoch 199 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 200 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 201 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 202 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 203 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 204 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 205 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 206 completed.
# 2024-09-12T23:35:17Z train-time-gan: INFO Epoch 207 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 208 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 209 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 210 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 211 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 212 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 213 completed.
# 2024-09-12T23:35:18Z train-time-gan: INFO Epoch 214 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 215 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 216 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 217 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 218 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 219 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 220 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 221 completed.
# 2024-09-12T23:35:19Z train-time-gan: INFO Epoch 222 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 223 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 224 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 225 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 226 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 227 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 228 completed.
# 2024-09-12T23:35:20Z train-time-gan: INFO Epoch 229 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 230 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 231 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 232 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 233 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 234 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 235 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 236 completed.
# 2024-09-12T23:35:21Z train-time-gan: INFO Epoch 237 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 238 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 239 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 240 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 241 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 242 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 243 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 244 completed.
# 2024-09-12T23:35:22Z train-time-gan: INFO Epoch 245 completed.
# 2024-09-12T23:35:23Z train-time-gan: INFO Epoch 246 completed.
# 2024-09-12T23:35:23Z train-time-gan: INFO Epoch 247 completed.
# 2024-09-12T23:35:23Z train-time-gan: INFO Epoch 248 completed.
# 2024-09-12T23:35:23Z train-time-gan: INFO Epoch 249 completed.
# 2024-09-12T23:35:23Z train-time-gan: INFO Epoch 250 completed.
# 2024-09-12T23:35:25Z train-time-gan: INFO Training completed. Uploaded model af629d1d-715f-11ef-a845-0a56df3a7c18

# %%
(await (await workflow.models().last()).add_labels(conn,location='location1')).labels
# Out:
# {'location': 'location1', 'workflow_id': '6UfjK0pqV7S2RN3syFcVH2'}
